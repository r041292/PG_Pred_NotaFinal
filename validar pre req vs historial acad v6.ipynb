# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re
import time
from collections import defaultdict

prereq = "para trabajar pre req progv22025-09-26160704_procesado_v3.xlsx"
#historial = "detalle matricula cohorte 2019.xlsx"
#historial = "detalle matricula cohorte 2019-2025.xlsx"
historial = "detalle matricula cohorte 2019-202610.csv"

# %%
def evaluar_prerrequisitos_mejorado(df_historial: pd.DataFrame, df_prereq: pd.DataFrame, debug_max_filas: int = 5) -> pd.DataFrame:
    """
    Evalúa prerrequisitos para cada fila del historial académico y devuelve el historial
    con columnas Prereq_i_* + Observacion_Prerrequisito.

    Reglas clave:
      - Aprobación = Materia_Aprobada == 'Y' (sin importar nota).
      - Temporal: aprobación debe ser en Periodo < Periodo de la materia.
      - Selección de opción:
          1) Prioriza opciones COMPLETAMENTE cumplidas.
          2) Entre opciones completas: prioriza las que tienen múltiples códigos (&) y luego menor número de opción.
          3) Si no hay completas, elige la mejor PARCIAL (más códigos aprobados; mismo desempate).
      - Si no hay opciones → "No tiene pre requisito".
      - Si hay opciones pero ninguna cumple ni parcialmente → "Tiene pre requisito pero no cumple".
      - No repetir códigos en la opción elegida (dedup ordenado).
      - Nivel=1, Tipo='Directo', EsCadena='FALSO' (no se construyen cadenas en esta función).

    Parámetros:
      - debug_max_filas: cuántas filas del historial mostrar con prints detallados (para depuración).
    """

    print("=== INICIO evaluar_prerrequisitos_mejorado ===")
    print(f"Historial: {df_historial.shape[0]} filas, {df_historial.shape[1]} cols")
    print(f"Prerrequisitos: {df_prereq.shape[0]} filas, {df_prereq.shape[1]} cols")

    # -------- Normalización mínima --------
    H = df_historial.copy()
    H['Periodo'] = pd.to_numeric(H['Periodo'], errors='coerce').astype('Int64')
    H['Materia_Aprobada'] = H['Materia_Aprobada'].astype(str).str.upper().fillna('')

    # Índice rápido por (Pidm, Cod, Periodo) ordenado
    H_sorted = H.sort_values(['Pidm','Cod materia curso','Periodo']).reset_index(drop=True)
    grp = H_sorted.groupby(['Pidm','Cod materia curso'], sort=False)

    def obtener_estado(pidm, cod, periodo_lim):
        """Devuelve (nota_ultima, intentos, aprobado_bool) considerando Periodo < periodo_lim."""
        try:
            g = grp.get_group((pidm, cod))
        except KeyError:
            return (None, 0, False)
        g_pre = g[g['Periodo'] < periodo_lim]
        if g_pre.empty:
            return (None, 0, False)
        ultimo = g_pre.iloc[-1]
        nota = ultimo.get('Calificacion_Final', None)
        intentos = len(g_pre)
        aprobado = (ultimo['Materia_Aprobada'] == 'Y')
        return (nota, intentos, aprobado)

    # -------- Construcción de opciones desde df_prereq --------
    patron = r'^Opcion_Prereq_\d+$'
    cols_opc = [c for c in df_prereq.columns if re.match(patron, c)]
    cols_opc.sort(key=lambda x: int(x.split('_')[-1]))
    print(f"Opciones detectadas: {cols_opc}")

    if not cols_opc:
        print("No hay columnas Opcion_Prereq_* en df_prereq → marcar todo como 'No tiene pre requisito'")
        out = H.copy()
        out['Observacion_Prerrequisito'] = 'No tiene pre requisito'
        return out

    PR = df_prereq.copy()
    PR_long = PR.melt(
        id_vars=['Smbarul_Key_Rule','Programa'],
        value_vars=cols_opc,
        var_name='Opcion',
        value_name='Prerrequisitos_Raw'
    ).dropna(subset=['Prerrequisitos_Raw'])

    if PR_long.empty:
        print("No hay valores en opciones de prerrequisito → marcar 'No tiene pre requisito'")
        out = H.copy()
        out['Observacion_Prerrequisito'] = 'No tiene pre requisito'
        return out

    # Parseo de códigos y metadata para orden estable
    def parse_lista(x):
        return [c.strip() for c in str(x).split('&') if str(c).strip()]

    PR_long['Codigos'] = PR_long['Prerrequisitos_Raw'].apply(parse_lista)
    PR_long['Opcion_Num'] = PR_long['Opcion'].str.extract(r'(\d+)').astype(int)
    PR_long['Es_Multi'] = PR_long['Codigos'].apply(lambda L: len(L) > 1)
    PR_long['RowOrder'] = np.arange(len(PR_long))  # orden estable para desempates

    print(f"Opciones en largo: {len(PR_long)} filas (materia/programa/opción)")

    # Index por materia para lookup rápido (trae TODAS las opciones de TODOS los programas)
    opciones_por_materia = defaultdict(list)
    for _, r in PR_long.iterrows():
        opciones_por_materia[r['Smbarul_Key_Rule']].append({
            'Programa'   : r['Programa'],
            'Opcion'     : r['Opcion'],
            'Opcion_Num' : int(r['Opcion_Num']),
            'Codigos'    : list(r['Codigos']),
            'Es_Multi'   : bool(r['Es_Multi']),
            'RowOrder'   : int(r['RowOrder'])
        })

    # -------- Evaluación fila a fila --------
    resultados = []
    n = len(H_sorted)
    print(f"Evaluando {n} filas del historial...")

    for idx, fila in H_sorted.iterrows():
        pidm    = fila['Pidm']
        materia = fila['Cod materia curso']
        periodo = int(fila['Periodo'])

        if idx < debug_max_filas:
            print(f"\n[DEBUG fila {idx}] Pidm={pidm}, Materia={materia}, Periodo={periodo}")

        opciones = opciones_por_materia.get(materia, [])
        if not opciones:
            # No hay prerrequisitos definidos para esta materia
            resultados.append((pidm, materia, periodo, 'No tiene pre requisito', []))
            if idx < debug_max_filas:
                print("  - Sin opciones en catálogo → No tiene pre requisito")
            continue

        # Orden de prioridad: MULTI primero, luego menor Opcion_Num, luego RowOrder (estable)
        opciones_ord = sorted(opciones, key=lambda d: (-int(d['Es_Multi']), int(d['Opcion_Num']), int(d['RowOrder'])))

        mejor_completa = None
        mejor_parcial  = None
        mejor_parcial_score = -1  # número de aprobados en esa opción

        # Recorremos opciones en orden de prioridad
        for op in opciones_ord:
            cods = op['Codigos']
            estado_codigos = []
            aprob_count = 0

            # Evaluación de cada código del prerrequisito
            for cod in cods:
                nota, intentos, aprobado = obtener_estado(pidm, cod, periodo)
                estado_codigos.append((cod, nota, intentos, aprobado))
                if aprobado:
                    aprob_count += 1

            # ¿Opción completamente cumplida?
            if aprob_count == len(cods):
                mejor_completa = (op, estado_codigos)
                if idx < debug_max_filas:
                    print(f"  - Opción COMPLETA encontrada: {op['Opcion']} ({'&' if op['Es_Multi'] else 'simple'}) → se elige y se detiene la búsqueda")
                break  # ya encontramos la mejor completa por nuestra prioridad

            # ¿Opción parcialmente cumplida? (al menos un aprobado)
            if aprob_count > 0 and aprob_count > mejor_parcial_score:
                mejor_parcial_score = aprob_count
                mejor_parcial = (op, estado_codigos)

        # Decidir resultado para la fila
        if mejor_completa is not None:
            op, lista = mejor_completa
            # Deduplicar códigos preservando orden
            vistos = set()
            lista_unica = []
            for cod, nota, intentos, aprobado in lista:
                if cod not in vistos:
                    lista_unica.append((cod, nota, intentos, aprobado))
                    vistos.add(cod)
            resultados.append((pidm, materia, periodo, 'Prerrequisito cumplido', lista_unica))
        elif mejor_parcial is not None:
            op, lista = mejor_parcial
            vistos = set()
            lista_unica = []
            for cod, nota, intentos, aprobado in lista:
                if cod not in vistos:
                    lista_unica.append((cod, nota, intentos, aprobado))
                    vistos.add(cod)
            resultados.append((pidm, materia, periodo, 'Cumple parcialmente el requisito', lista_unica))
            if idx < debug_max_filas:
                print(f"  - Mejor opción PARCIAL: {op['Opcion']} con {mejor_parcial_score} aprobados")
        else:
            resultados.append((pidm, materia, periodo, 'Tiene pre requisito pero no cumple', []))
            if idx < debug_max_filas:
                print("  - Ninguna opción cumple ni parcialmente → Tiene pre requisito pero no cumple")

        # Progreso
        if (idx + 1) % 10000 == 0:
            print(f"  ...procesadas {idx+1} filas")

    # -------- Construcción de salida en ancho --------
    filas_out = []
    for pidm, materia, periodo, obs, prereqs in resultados:
        fila = {
            'Pidm': pidm,
            'Cod materia curso': materia,
            'Periodo': periodo,
            'Observacion_Prerrequisito': obs
        }
        # Solo los de la opción elegida (completa o parcial). Sin duplicados.
        for i, (codigo, nota, intentos, aprobado) in enumerate(prereqs, start=1):
            fila[f'Prereq_{i}_Codigo']    = codigo
            fila[f'Prereq_{i}_Nota']      = nota
            fila[f'Prereq_{i}_Intentos']  = intentos
            fila[f'Prereq_{i}_Nivel']     = 1
            fila[f'Prereq_{i}_Tipo']      = 'Directo'
            fila[f'Prereq_{i}_EsCadena']  = 'FALSO'
        filas_out.append(fila)

    df_result = pd.DataFrame(filas_out)
    print(f"\nFilas con evaluación: {df_result.shape[0]}. Columnas generadas (máx): {df_result.shape[1]}")

    # Métricas de observación
    if 'Observacion_Prerrequisito' in df_result.columns:
        print("\nResumen Observacion_Prerrequisito:")
        print(df_result['Observacion_Prerrequisito'].value_counts(dropna=False))

    # -------- Merge no destructivo: historial + nuevas columnas --------
    df_final = H.merge(df_result, on=['Pidm','Cod materia curso','Periodo'], how='left')
    print("=== FIN evaluar_prerrequisitos_mejorado ===\n")
    return df_final

# %%
def guardar_resultados(df):
        """Guarda los resultados en un archivo Excel"""
        if df is None:
            print("No hay resultados para guardar")
            return

        timestamp = pd.Timestamp.now().strftime("%Y-%m-%d%H%M%S")
        #nombre_archivo = "Resultados v6/resultados_prerrequisitos_v6_cadenas_"+timestamp+".xlsx"
        nombre_archivo = "Resultados v6/resultados_prerrequisitos_v6_cadenas_"+timestamp+".csv"

        try:
            # Limpiar columnas completamente vacías
            df = df.dropna(axis=1, how='all')
            print(f"✓ Guardando resultados en: {nombre_archivo} ...")
            #df.to_excel(nombre_archivo, index=False)
            df.to_csv(nombre_archivo, index=False)
            print(f"✓ Resultados guardados en: {nombre_archivo}")
            print(f"Columnas en el archivo: {len(df.columns)}")
        except Exception as e:
            print(f"Error al guardar resultados: {e}")

# %%
def evaluar_prerrequisitos_con_cadena(df_historial: pd.DataFrame,
                                      df_prereq: pd.DataFrame,
                                      debug_max_filas: int = 5,
                                      debug_imprime_n: int = 10) -> pd.DataFrame:
    """
    Evalúa prerrequisitos directos y en cadena (hasta 'debug_max_filas' niveles)
    para cada fila del historial. Devuelve el historial expandido con:

      - Observacion_Prerrequisito ∈ {
          'Prerrequisito cumplido',
          'Cumple parcialmente el requisito',
          'Tiene pre requisito pero no cumple',
          'No tiene pre requisito'
        }
      - Prereq_i_Codigo / Nota / Intentos / Nivel / Tipo / EsCadena

    Reglas:
      - Aprobación: Materia_Aprobada == 'Y' (nota no define aprobación).
      - Temporal: la aprobación válida debe estar en Periodo < Periodo de la materia raíz.
      - Selección de opción:
          1) Primero opciones COMPLETAS; prioriza las que tienen '&'.
          2) Si no hay completas → mejor PARCIAL (más aprobados; empate: '&' > simple > menor Opcion_Num).
          3) Si no hay completas ni parciales → “Tiene pre requisito pero no cumple”.
      - Cadena: se expande recursivamente por la opción ELEGIDA de cada curso (directo/cadena),
        sin repetir códigos (dedup por materia raíz).
    """

    print("=== INICIO evaluar_prerrequisitos_con_cadena ===")
    print(f"Historial: {df_historial.shape[0]} filas, {df_historial.shape[1]} cols")
    print(f"Prerrequisitos: {df_prereq.shape[0]} filas, {df_prereq.shape[1]} cols")

    # ---------------- Normalización mínima ----------------
    H = df_historial.copy()
    H['Periodo'] = pd.to_numeric(H['Periodo'], errors='coerce').astype('Int64')
    H['Materia_Aprobada'] = H['Materia_Aprobada'].astype(str).str.upper().fillna('')

    # Índice rápido por (Pidm, Cod, Periodo) ordenado
    H_sorted = H.sort_values(['Pidm','Cod materia curso','Periodo']).reset_index(drop=True)
    grp = H_sorted.groupby(['Pidm','Cod materia curso'], sort=False)

    def obtener_estado(pidm, cod, periodo_lim):
        """Devuelve (nota_ultima, intentos, aprobado_bool) considerando Periodo < periodo_lim."""
        try:
            g = grp.get_group((pidm, cod))
        except KeyError:
            return (None, 0, False)
        g_pre = g[g['Periodo'] < periodo_lim]
        if g_pre.empty:
            return (None, 0, False)
        ultimo = g_pre.iloc[-1]
        nota = ultimo.get('Calificacion_Final', None)
        intentos = len(g_pre)
        aprobado = (ultimo['Materia_Aprobada'] == 'Y')
        return (nota, intentos, aprobado)

    # ---------------- Catálogo de opciones (melt + parse) ----------------
    patron = r'^Opcion_Prereq_\d+$'
    cols_opc = [c for c in df_prereq.columns if re.match(patron, c)]
    cols_opc.sort(key=lambda x: int(x.split('_')[-1]))
    print(f"Opciones detectadas: {cols_opc}")

    if not cols_opc:
        print("No hay columnas Opcion_Prereq_* en df_prereq → marcar todo como 'No tiene pre requisito'")
        out = H.copy()
        out['Observacion_Prerrequisito'] = 'No tiene pre requisito'
        return out

    PR = df_prereq.copy()
    PR_long = PR.melt(
        id_vars=['Smbarul_Key_Rule','Programa'],
        value_vars=cols_opc,
        var_name='Opcion',
        value_name='Prerrequisitos_Raw'
    ).dropna(subset=['Prerrequisitos_Raw'])

    if PR_long.empty:
        print("No hay valores en opciones de prerrequisito → marcar 'No tiene pre requisito'")
        out = H.copy()
        out['Observacion_Prerrequisito'] = 'No tiene pre requisito'
        return out

    # Parseo de códigos: "A & B" → ["A","B"]
    def parse_lista(x):
        return [c.strip() for c in str(x).split('&') if str(c).strip()]

    PR_long['Codigos']    = PR_long['Prerrequisitos_Raw'].apply(parse_lista)
    PR_long['Opcion_Num'] = PR_long['Opcion'].str.extract(r'(\d+)').astype(int)
    PR_long['Es_Multi']   = PR_long['Codigos'].apply(lambda L: len(L) > 1)
    PR_long['RowOrder']   = np.arange(len(PR_long))  # orden estable para desempates

    print(f"Opciones en largo (materia/programa/opción): {len(PR_long)} filas")

    # Index de opciones por materia (unimos todas las filas de todos los programas)
    opciones_por_materia = defaultdict(list)
    for _, r in PR_long.iterrows():
        opciones_por_materia[r['Smbarul_Key_Rule']].append({
            'Programa'   : r['Programa'],
            'Opcion'     : r['Opcion'],
            'Opcion_Num' : int(r['Opcion_Num']),
            'Codigos'    : list(r['Codigos']),
            'Es_Multi'   : bool(r['Es_Multi']),
            'RowOrder'   : int(r['RowOrder'])
        })

    # ---------------- Selección de opción (reglas de prioridad) ----------------
    def seleccionar_opcion(pidm, materia, periodo):
        """
        Devuelve (estado_global, lista_detalles) donde:
          - estado_global ∈ {"cumple","parcial","no","sin_opciones"}
          - lista_detalles = [(cod, nota, intentos, aprobado_bool), ...] de la opción ELEGIDA
            (o [] si "no" o "sin_opciones")
        """
        opciones = opciones_por_materia.get(materia, [])
        if not opciones:
            return "sin_opciones", []

        # Orden de prioridad: MULTI primero, luego menor Opcion_Num, luego RowOrder
        opciones_ord = sorted(opciones, key=lambda d: (-int(d['Es_Multi']), int(d['Opcion_Num']), int(d['RowOrder'])))

        mejor_completa = None
        mejor_parcial  = None
        mejor_parcial_score = -1

        for op in opciones_ord:
            cods = op['Codigos']
            detalles = []
            aprob_count = 0

            for cod in cods:
                nota, intentos, aprobado = obtener_estado(pidm, cod, periodo)
                detalles.append((cod, nota, intentos, aprobado))
                if aprobado:
                    aprob_count += 1

            if aprob_count == len(cods):
                # opción completamente cumplida → devolver de una
                return "cumple", detalles

            if aprob_count > 0 and aprob_count > mejor_parcial_score:
                mejor_parcial_score = aprob_count
                mejor_parcial = detalles

        if mejor_parcial is not None:
            return "parcial", mejor_parcial

        return "no", []

    # ---------------- Recursión para cadena ----------------
    def expandir_cadena(pidm, materia, periodo, nivel, visitados):
        """
        Expande recursivamente los prerrequisitos de 'materia' elegidos por las reglas,
        acumulando códigos (sin repetir) con metadata. Devuelve lista de tuplas:
          (codigo, nota, intentos, aprobado_bool, nivel, tipo, es_cadena)
        """
        if nivel > debug_max_filas:
            return []

        estado, detalles = seleccionar_opcion(pidm, materia, periodo)
        resultado_nivel = []

        if estado in ("cumple", "parcial"):
            # Añadir los códigos de la opción ELEGIDA de esta 'materia'
            for cod, nota, intentos, aprobado in detalles:
                if cod not in visitados:
                    resultado_nivel.append((cod, nota, intentos, aprobado,
                                            nivel,
                                            'Directo' if nivel == 1 else 'Cadena',
                                            'FALSO'   if nivel == 1 else 'VERDADERO'))
                    visitados.add(cod)

            # Expandir siguiente nivel para CADA código elegido
            for cod, _, _, _ in detalles:
                resultado_nivel.extend(expandir_cadena(pidm, cod, periodo, nivel+1, visitados))

        # Si no hay opción elegible (estado "no") o "sin_opciones", no hay cadena por esta rama
        return resultado_nivel

    # ---------------- Evaluación fila a fila ----------------
    resultados = []
    n = len(H_sorted)
    print(f"Evaluando {n} filas del historial...")

    for idx, row in H_sorted.iterrows():
        pidm    = row['Pidm']
        materia = row['Cod materia curso']
        periodo = int(row['Periodo'])

         # Progreso con porcentaje
        if (idx + 1) % 500 == 0 or (idx + 1) == n:  # ajusta 500 al intervalo que prefieras
            print(f"Revisado {idx+1} / {n} lineas ({(idx+1)/n:.1%})")

        if idx < debug_imprime_n:
            print(f"\n[DEBUG fila {idx}] Pidm={pidm}, Materia={materia}, Periodo={periodo}")

        # 1) Selección de opción al NIVEL 1 (para Observacion)
        estado_root, detalles_root = seleccionar_opcion(pidm, materia, periodo)
        if estado_root == "sin_opciones":
            obs = "No tiene pre requisito"
            lista_total = []
            if idx < debug_imprime_n:
                print("  - Sin opciones → No tiene pre requisito")
        elif estado_root == "cumple":
            obs = "Prerrequisito cumplido"
            if idx < debug_imprime_n:
                print(f"  - Opción nivel 1: COMPLETA (directos)")
            # 2) Expandir cadena desde la materia raíz (incluye directos y cadena)
            visitados = set()
            lista_total = expandir_cadena(pidm, materia, periodo, nivel=1, visitados=visitados)
        elif estado_root == "parcial":
            obs = "Cumple parcialmente el requisito"
            if idx < debug_imprime_n:
                print(f"  - Opción nivel 1: PARCIAL (directos)")
            visitados = set()
            lista_total = expandir_cadena(pidm, materia, periodo, nivel=1, visitados=visitados)
        else:  # "no"
            obs = "Tiene pre requisito pero no cumple"
            lista_total = []
            if idx < debug_imprime_n:
                print("  - Ninguna opción de nivel 1 cumple ni parcialmente")

        # 3) Quitar duplicados preservando orden (por seguridad)
        seen = set()
        lista_unica = []
        for item in lista_total:
            cod = item[0]
            if cod not in seen:
                lista_unica.append(item)
                seen.add(cod)

        # 4) Armar fila de salida
        out_row = row.to_dict()
        out_row['Observacion_Prerrequisito'] = obs

        for j, (codigo, nota, intentos, aprobado, nivel, tipo, es_cadena) in enumerate(lista_unica, start=1):
            out_row[f'Prereq_{j}_Codigo']    = codigo
            out_row[f'Prereq_{j}_Nota']      = nota
            out_row[f'Prereq_{j}_Intentos']  = intentos
            out_row[f'Prereq_{j}_Nivel']     = nivel
            out_row[f'Prereq_{j}_Tipo']      = tipo
            out_row[f'Prereq_{j}_EsCadena']  = es_cadena

        resultados.append(out_row)

        # Progreso
        if (idx + 1) % 10000 == 0:
            print(f"  ...procesadas {idx+1} filas")

    df_final = pd.DataFrame(resultados)
    print("\nResumen Observacion_Prerrequisito:")
    print(df_final['Observacion_Prerrequisito'].value_counts(dropna=False))
    print("=== FIN evaluar_prerrequisitos_con_cadena ===\n")
    return df_final

# %%
print("=== ANALIZADOR OPTIMIZADO DE PRERREQUISITOS CON CADENAS ===\n")

# Solicitar archivo de prerrequisitos
while True:
    try:
        ruta_prereq = prereq #input("Ingrese la ruta del archivo 'pre_requisitos.xlsx': ").strip()
        df_prereq = pd.read_excel(ruta_prereq)
        print(f"✓ Archivo de prerrequisitos cargado: {len(df_prereq)} registros")
        break
    except Exception as e:
        print(f"Error al cargar prerrequisitos: {e}")
        print("Intente nuevamente.\n")

# Solicitar archivo de historial
while True:
    try:
        ruta_historial = historial#input("Ingrese la ruta del archivo 'historial_asignaturas.xlsx': ").strip()
        #df_historial = pd.read_excel(ruta_historial)
        df_historial = pd.read_csv(ruta_historial, sep=';')
        print(f"✓ Archivo de historial cargado: {len(df_historial)} registros")
        break
    except Exception as e:
        print(f"Error al cargar historial: {e}")
        print("Intente nuevamente.\n")
# Out:
# === ANALIZADOR OPTIMIZADO DE PRERREQUISITOS CON CADENAS ===
#
# ✓ Archivo de prerrequisitos cargado: 3101 registros
# C:\Users\vittorinor\AppData\Local\Temp\ipykernel_25176\450024230.py:19: DtypeWarning: Columns (4,5,9,15,16,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_historial = pd.read_csv(ruta_historial, sep=';')
# ✓ Archivo de historial cargado: 690827 registros

# %%
df_final = evaluar_prerrequisitos_con_cadena(df_historial, df_prereq)#evaluar_prerrequisitos_mejorado(df_historial, df_prereq)
# Out:
# === INICIO evaluar_prerrequisitos_con_cadena ===
# Historial: 690827 filas, 39 cols
# Prerrequisitos: 3101 filas, 64 cols
# Opciones detectadas: ['Opcion_Prereq_1', 'Opcion_Prereq_2', 'Opcion_Prereq_3', 'Opcion_Prereq_4', 'Opcion_Prereq_5', 'Opcion_Prereq_6', 'Opcion_Prereq_7', 'Opcion_Prereq_8', 'Opcion_Prereq_9', 'Opcion_Prereq_10', 'Opcion_Prereq_11', 'Opcion_Prereq_12', 'Opcion_Prereq_13', 'Opcion_Prereq_14', 'Opcion_Prereq_15', 'Opcion_Prereq_16', 'Opcion_Prereq_17', 'Opcion_Prereq_18', 'Opcion_Prereq_19', 'Opcion_Prereq_20', 'Opcion_Prereq_21', 'Opcion_Prereq_22', 'Opcion_Prereq_23', 'Opcion_Prereq_24', 'Opcion_Prereq_25', 'Opcion_Prereq_26', 'Opcion_Prereq_27', 'Opcion_Prereq_28', 'Opcion_Prereq_29', 'Opcion_Prereq_30', 'Opcion_Prereq_31', 'Opcion_Prereq_32', 'Opcion_Prereq_33', 'Opcion_Prereq_34', 'Opcion_Prereq_35', 'Opcion_Prereq_36', 'Opcion_Prereq_37', 'Opcion_Prereq_38', 'Opcion_Prereq_39', 'Opcion_Prereq_40', 'Opcion_Prereq_41', 'Opcion_Prereq_42', 'Opcion_Prereq_43', 'Opcion_Prereq_44', 'Opcion_Prereq_45', 'Opcion_Prereq_46', 'Opcion_Prereq_47', 'Opcion_Prereq_48', 'Opcion_Prereq_49', 'Opcion_Prereq_50', 'Opcion_Prereq_51', 'Opcion_Prereq_52', 'Opcion_Prereq_53', 'Opcion_Prereq_54', 'Opcion_Prereq_55', 'Opcion_Prereq_56']
# Opciones en largo (materia/programa/opción): 2854 filas
# Evaluando 690827 filas del historial...
#
# [DEBUG fila 0] Pidm=18782, Materia=CAS3020, Periodo=202030
#   - Sin opciones → No tiene pre requisito
#
# [DEBUG fila 1] Pidm=18782, Materia=MUS4030, Periodo=202030
#   - Ninguna opción de nivel 1 cumple ni parcialmente
#
# [DEBUG fila 2] Pidm=18782, Materia=MUS4060, Periodo=202030
#   - Sin opciones → No tiene pre requisito
#
# [DEBUG fila 3] Pidm=18782, Materia=MUS4090, Periodo=202030
#   - Ninguna opción de nivel 1 cumple ni parcialmente
#
# [DEBUG fila 4] Pidm=18782, Materia=MUS4110, Periodo=202030
#   - Sin opciones → No tiene pre requisito
#
# [DEBUG fila 5] Pidm=18782, Materia=MUS4155, Periodo=202030
#   - Ninguna opción de nivel 1 cumple ni parcialmente
#
# [DEBUG fila 6] Pidm=18782, Materia=MUS7446, Periodo=202030
#   - Sin opciones → No tiene pre requisito
#
# [DEBUG fila 7] Pidm=18782, Materia=PML0031, Periodo=202030
#   - Sin opciones → No tiene pre requisito
#
# [DEBUG fila 8] Pidm=18782, Materia=PML0529, Periodo=202030
#   - Sin opciones → No tiene pre requisito
#
# [DEBUG fila 9] Pidm=60755, Materia=CAS3020, Periodo=202330
#   - Sin opciones → No tiene pre requisito
# Revisado 500 / 690827 lineas (0.1%)
# Revisado 1000 / 690827 lineas (0.1%)
# Revisado 1500 / 690827 lineas (0.2%)
# Revisado 2000 / 690827 lineas (0.3%)
# Revisado 2500 / 690827 lineas (0.4%)
# Revisado 3000 / 690827 lineas (0.4%)
# Revisado 3500 / 690827 lineas (0.5%)
# Revisado 4000 / 690827 lineas (0.6%)
# Revisado 4500 / 690827 lineas (0.7%)
# Revisado 5000 / 690827 lineas (0.7%)
# Revisado 5500 / 690827 lineas (0.8%)
# Revisado 6000 / 690827 lineas (0.9%)
# Revisado 6500 / 690827 lineas (0.9%)
# Revisado 7000 / 690827 lineas (1.0%)
# Revisado 7500 / 690827 lineas (1.1%)
# Revisado 8000 / 690827 lineas (1.2%)
# Revisado 8500 / 690827 lineas (1.2%)
# Revisado 9000 / 690827 lineas (1.3%)
# Revisado 9500 / 690827 lineas (1.4%)
# Revisado 10000 / 690827 lineas (1.4%)
#   ...procesadas 10000 filas
# Revisado 10500 / 690827 lineas (1.5%)
# Revisado 11000 / 690827 lineas (1.6%)
# Revisado 11500 / 690827 lineas (1.7%)
# Revisado 12000 / 690827 lineas (1.7%)
# Revisado 12500 / 690827 lineas (1.8%)
# Revisado 13000 / 690827 lineas (1.9%)
# Revisado 13500 / 690827 lineas (2.0%)
# Revisado 14000 / 690827 lineas (2.0%)
# Revisado 14500 / 690827 lineas (2.1%)
# Revisado 15000 / 690827 lineas (2.2%)
# Revisado 15500 / 690827 lineas (2.2%)
# Revisado 16000 / 690827 lineas (2.3%)
# Revisado 16500 / 690827 lineas (2.4%)
# Revisado 17000 / 690827 lineas (2.5%)
# Revisado 17500 / 690827 lineas (2.5%)
# Revisado 18000 / 690827 lineas (2.6%)
# Revisado 18500 / 690827 lineas (2.7%)
# Revisado 19000 / 690827 lineas (2.8%)
# Revisado 19500 / 690827 lineas (2.8%)
# Revisado 20000 / 690827 lineas (2.9%)
#   ...procesadas 20000 filas
# Revisado 20500 / 690827 lineas (3.0%)
# Revisado 21000 / 690827 lineas (3.0%)
# Revisado 21500 / 690827 lineas (3.1%)
# Revisado 22000 / 690827 lineas (3.2%)
# Revisado 22500 / 690827 lineas (3.3%)
# Revisado 23000 / 690827 lineas (3.3%)
# Revisado 23500 / 690827 lineas (3.4%)
# Revisado 24000 / 690827 lineas (3.5%)
# Revisado 24500 / 690827 lineas (3.5%)
# Revisado 25000 / 690827 lineas (3.6%)
# Revisado 25500 / 690827 lineas (3.7%)
# Revisado 26000 / 690827 lineas (3.8%)
# Revisado 26500 / 690827 lineas (3.8%)
# Revisado 27000 / 690827 lineas (3.9%)
# Revisado 27500 / 690827 lineas (4.0%)
# Revisado 28000 / 690827 lineas (4.1%)
# Revisado 28500 / 690827 lineas (4.1%)
# Revisado 29000 / 690827 lineas (4.2%)
# Revisado 29500 / 690827 lineas (4.3%)
# Revisado 30000 / 690827 lineas (4.3%)
#   ...procesadas 30000 filas
# Revisado 30500 / 690827 lineas (4.4%)
# Revisado 31000 / 690827 lineas (4.5%)
# Revisado 31500 / 690827 lineas (4.6%)
# Revisado 32000 / 690827 lineas (4.6%)
# Revisado 32500 / 690827 lineas (4.7%)
# Revisado 33000 / 690827 lineas (4.8%)
# Revisado 33500 / 690827 lineas (4.8%)
# Revisado 34000 / 690827 lineas (4.9%)
# Revisado 34500 / 690827 lineas (5.0%)
# Revisado 35000 / 690827 lineas (5.1%)
# Revisado 35500 / 690827 lineas (5.1%)
# Revisado 36000 / 690827 lineas (5.2%)
# Revisado 36500 / 690827 lineas (5.3%)
# Revisado 37000 / 690827 lineas (5.4%)
# Revisado 37500 / 690827 lineas (5.4%)
# Revisado 38000 / 690827 lineas (5.5%)
# Revisado 38500 / 690827 lineas (5.6%)
# Revisado 39000 / 690827 lineas (5.6%)
# Revisado 39500 / 690827 lineas (5.7%)
# Revisado 40000 / 690827 lineas (5.8%)
#   ...procesadas 40000 filas
# Revisado 40500 / 690827 lineas (5.9%)
# Revisado 41000 / 690827 lineas (5.9%)
# Revisado 41500 / 690827 lineas (6.0%)
# Revisado 42000 / 690827 lineas (6.1%)
# Revisado 42500 / 690827 lineas (6.2%)
# Revisado 43000 / 690827 lineas (6.2%)
# Revisado 43500 / 690827 lineas (6.3%)
# Revisado 44000 / 690827 lineas (6.4%)
# Revisado 44500 / 690827 lineas (6.4%)
# Revisado 45000 / 690827 lineas (6.5%)
# Revisado 45500 / 690827 lineas (6.6%)
# Revisado 46000 / 690827 lineas (6.7%)
# Revisado 46500 / 690827 lineas (6.7%)
# Revisado 47000 / 690827 lineas (6.8%)
# Revisado 47500 / 690827 lineas (6.9%)
# Revisado 48000 / 690827 lineas (6.9%)
# Revisado 48500 / 690827 lineas (7.0%)
# Revisado 49000 / 690827 lineas (7.1%)
# Revisado 49500 / 690827 lineas (7.2%)
# Revisado 50000 / 690827 lineas (7.2%)
#   ...procesadas 50000 filas
# Revisado 50500 / 690827 lineas (7.3%)
# Revisado 51000 / 690827 lineas (7.4%)
# Revisado 51500 / 690827 lineas (7.5%)
# Revisado 52000 / 690827 lineas (7.5%)
# Revisado 52500 / 690827 lineas (7.6%)
# Revisado 53000 / 690827 lineas (7.7%)
# Revisado 53500 / 690827 lineas (7.7%)
# Revisado 54000 / 690827 lineas (7.8%)
# Revisado 54500 / 690827 lineas (7.9%)
# Revisado 55000 / 690827 lineas (8.0%)
# Revisado 55500 / 690827 lineas (8.0%)
# Revisado 56000 / 690827 lineas (8.1%)
# Revisado 56500 / 690827 lineas (8.2%)
# Revisado 57000 / 690827 lineas (8.3%)
# Revisado 57500 / 690827 lineas (8.3%)
# Revisado 58000 / 690827 lineas (8.4%)
# Revisado 58500 / 690827 lineas (8.5%)
# Revisado 59000 / 690827 lineas (8.5%)
# Revisado 59500 / 690827 lineas (8.6%)
# Revisado 60000 / 690827 lineas (8.7%)
#   ...procesadas 60000 filas
# Revisado 60500 / 690827 lineas (8.8%)
# Revisado 61000 / 690827 lineas (8.8%)
# Revisado 61500 / 690827 lineas (8.9%)
# Revisado 62000 / 690827 lineas (9.0%)
# Revisado 62500 / 690827 lineas (9.0%)
# Revisado 63000 / 690827 lineas (9.1%)
# Revisado 63500 / 690827 lineas (9.2%)
# Revisado 64000 / 690827 lineas (9.3%)
# Revisado 64500 / 690827 lineas (9.3%)
# Revisado 65000 / 690827 lineas (9.4%)
# Revisado 65500 / 690827 lineas (9.5%)
# Revisado 66000 / 690827 lineas (9.6%)
# Revisado 66500 / 690827 lineas (9.6%)
# Revisado 67000 / 690827 lineas (9.7%)
# Revisado 67500 / 690827 lineas (9.8%)
# Revisado 68000 / 690827 lineas (9.8%)
# Revisado 68500 / 690827 lineas (9.9%)
# Revisado 69000 / 690827 lineas (10.0%)
# Revisado 69500 / 690827 lineas (10.1%)
# Revisado 70000 / 690827 lineas (10.1%)
#   ...procesadas 70000 filas
# Revisado 70500 / 690827 lineas (10.2%)
# Revisado 71000 / 690827 lineas (10.3%)
# Revisado 71500 / 690827 lineas (10.3%)
# Revisado 72000 / 690827 lineas (10.4%)
# Revisado 72500 / 690827 lineas (10.5%)
# Revisado 73000 / 690827 lineas (10.6%)
# Revisado 73500 / 690827 lineas (10.6%)
# Revisado 74000 / 690827 lineas (10.7%)
# Revisado 74500 / 690827 lineas (10.8%)
# Revisado 75000 / 690827 lineas (10.9%)
# Revisado 75500 / 690827 lineas (10.9%)
# Revisado 76000 / 690827 lineas (11.0%)
# Revisado 76500 / 690827 lineas (11.1%)
# Revisado 77000 / 690827 lineas (11.1%)
# Revisado 77500 / 690827 lineas (11.2%)
# Revisado 78000 / 690827 lineas (11.3%)
# Revisado 78500 / 690827 lineas (11.4%)
# Revisado 79000 / 690827 lineas (11.4%)
# Revisado 79500 / 690827 lineas (11.5%)
# Revisado 80000 / 690827 lineas (11.6%)
#   ...procesadas 80000 filas
# Revisado 80500 / 690827 lineas (11.7%)
# Revisado 81000 / 690827 lineas (11.7%)
# Revisado 81500 / 690827 lineas (11.8%)
# Revisado 82000 / 690827 lineas (11.9%)
# Revisado 82500 / 690827 lineas (11.9%)
# Revisado 83000 / 690827 lineas (12.0%)
# Revisado 83500 / 690827 lineas (12.1%)
# Revisado 84000 / 690827 lineas (12.2%)
# Revisado 84500 / 690827 lineas (12.2%)
# Revisado 85000 / 690827 lineas (12.3%)
# Revisado 85500 / 690827 lineas (12.4%)
# Revisado 86000 / 690827 lineas (12.4%)
# Revisado 86500 / 690827 lineas (12.5%)
# Revisado 87000 / 690827 lineas (12.6%)
# Revisado 87500 / 690827 lineas (12.7%)
# Revisado 88000 / 690827 lineas (12.7%)
# Revisado 88500 / 690827 lineas (12.8%)
# Revisado 89000 / 690827 lineas (12.9%)
# Revisado 89500 / 690827 lineas (13.0%)
# Revisado 90000 / 690827 lineas (13.0%)
#   ...procesadas 90000 filas
# Revisado 90500 / 690827 lineas (13.1%)
# Revisado 91000 / 690827 lineas (13.2%)
# Revisado 91500 / 690827 lineas (13.2%)
# Revisado 92000 / 690827 lineas (13.3%)
# Revisado 92500 / 690827 lineas (13.4%)
# Revisado 93000 / 690827 lineas (13.5%)
# Revisado 93500 / 690827 lineas (13.5%)
# Revisado 94000 / 690827 lineas (13.6%)
# Revisado 94500 / 690827 lineas (13.7%)
# Revisado 95000 / 690827 lineas (13.8%)
# Revisado 95500 / 690827 lineas (13.8%)
# Revisado 96000 / 690827 lineas (13.9%)
# Revisado 96500 / 690827 lineas (14.0%)
# Revisado 97000 / 690827 lineas (14.0%)
# Revisado 97500 / 690827 lineas (14.1%)
# Revisado 98000 / 690827 lineas (14.2%)
# Revisado 98500 / 690827 lineas (14.3%)
# Revisado 99000 / 690827 lineas (14.3%)
# Revisado 99500 / 690827 lineas (14.4%)
# Revisado 100000 / 690827 lineas (14.5%)
#   ...procesadas 100000 filas
# Revisado 100500 / 690827 lineas (14.5%)
# Revisado 101000 / 690827 lineas (14.6%)
# Revisado 101500 / 690827 lineas (14.7%)
# Revisado 102000 / 690827 lineas (14.8%)
# Revisado 102500 / 690827 lineas (14.8%)
# Revisado 103000 / 690827 lineas (14.9%)
# Revisado 103500 / 690827 lineas (15.0%)
# Revisado 104000 / 690827 lineas (15.1%)
# Revisado 104500 / 690827 lineas (15.1%)
# Revisado 105000 / 690827 lineas (15.2%)
# Revisado 105500 / 690827 lineas (15.3%)
# Revisado 106000 / 690827 lineas (15.3%)
# Revisado 106500 / 690827 lineas (15.4%)
# Revisado 107000 / 690827 lineas (15.5%)
# Revisado 107500 / 690827 lineas (15.6%)
# Revisado 108000 / 690827 lineas (15.6%)
# Revisado 108500 / 690827 lineas (15.7%)
# Revisado 109000 / 690827 lineas (15.8%)
# Revisado 109500 / 690827 lineas (15.9%)
# Revisado 110000 / 690827 lineas (15.9%)
#   ...procesadas 110000 filas
# Revisado 110500 / 690827 lineas (16.0%)
# Revisado 111000 / 690827 lineas (16.1%)
# Revisado 111500 / 690827 lineas (16.1%)
# Revisado 112000 / 690827 lineas (16.2%)
# Revisado 112500 / 690827 lineas (16.3%)
# Revisado 113000 / 690827 lineas (16.4%)
# Revisado 113500 / 690827 lineas (16.4%)
# Revisado 114000 / 690827 lineas (16.5%)
# Revisado 114500 / 690827 lineas (16.6%)
# Revisado 115000 / 690827 lineas (16.6%)
# Revisado 115500 / 690827 lineas (16.7%)
# Revisado 116000 / 690827 lineas (16.8%)
# Revisado 116500 / 690827 lineas (16.9%)
# Revisado 117000 / 690827 lineas (16.9%)
# Revisado 117500 / 690827 lineas (17.0%)
# Revisado 118000 / 690827 lineas (17.1%)
# Revisado 118500 / 690827 lineas (17.2%)
# Revisado 119000 / 690827 lineas (17.2%)
# Revisado 119500 / 690827 lineas (17.3%)
# Revisado 120000 / 690827 lineas (17.4%)
#   ...procesadas 120000 filas
# Revisado 120500 / 690827 lineas (17.4%)
# Revisado 121000 / 690827 lineas (17.5%)
# Revisado 121500 / 690827 lineas (17.6%)
# Revisado 122000 / 690827 lineas (17.7%)
# Revisado 122500 / 690827 lineas (17.7%)
# Revisado 123000 / 690827 lineas (17.8%)
# Revisado 123500 / 690827 lineas (17.9%)
# Revisado 124000 / 690827 lineas (17.9%)
# Revisado 124500 / 690827 lineas (18.0%)
# Revisado 125000 / 690827 lineas (18.1%)
# Revisado 125500 / 690827 lineas (18.2%)
# Revisado 126000 / 690827 lineas (18.2%)
# Revisado 126500 / 690827 lineas (18.3%)
# Revisado 127000 / 690827 lineas (18.4%)
# Revisado 127500 / 690827 lineas (18.5%)
# Revisado 128000 / 690827 lineas (18.5%)
# Revisado 128500 / 690827 lineas (18.6%)
# Revisado 129000 / 690827 lineas (18.7%)
# Revisado 129500 / 690827 lineas (18.7%)
# Revisado 130000 / 690827 lineas (18.8%)
#   ...procesadas 130000 filas
# Revisado 130500 / 690827 lineas (18.9%)
# Revisado 131000 / 690827 lineas (19.0%)
# Revisado 131500 / 690827 lineas (19.0%)
# Revisado 132000 / 690827 lineas (19.1%)
# Revisado 132500 / 690827 lineas (19.2%)
# Revisado 133000 / 690827 lineas (19.3%)
# Revisado 133500 / 690827 lineas (19.3%)
# Revisado 134000 / 690827 lineas (19.4%)
# Revisado 134500 / 690827 lineas (19.5%)
# Revisado 135000 / 690827 lineas (19.5%)
# Revisado 135500 / 690827 lineas (19.6%)
# Revisado 136000 / 690827 lineas (19.7%)
# Revisado 136500 / 690827 lineas (19.8%)
# Revisado 137000 / 690827 lineas (19.8%)
# Revisado 137500 / 690827 lineas (19.9%)
# Revisado 138000 / 690827 lineas (20.0%)
# Revisado 138500 / 690827 lineas (20.0%)
# Revisado 139000 / 690827 lineas (20.1%)
# Revisado 139500 / 690827 lineas (20.2%)
# Revisado 140000 / 690827 lineas (20.3%)
#   ...procesadas 140000 filas
# Revisado 140500 / 690827 lineas (20.3%)
# Revisado 141000 / 690827 lineas (20.4%)
# Revisado 141500 / 690827 lineas (20.5%)
# Revisado 142000 / 690827 lineas (20.6%)
# Revisado 142500 / 690827 lineas (20.6%)
# Revisado 143000 / 690827 lineas (20.7%)
# Revisado 143500 / 690827 lineas (20.8%)
# Revisado 144000 / 690827 lineas (20.8%)
# Revisado 144500 / 690827 lineas (20.9%)
# Revisado 145000 / 690827 lineas (21.0%)
# Revisado 145500 / 690827 lineas (21.1%)
# Revisado 146000 / 690827 lineas (21.1%)
# Revisado 146500 / 690827 lineas (21.2%)
# Revisado 147000 / 690827 lineas (21.3%)
# Revisado 147500 / 690827 lineas (21.4%)
# Revisado 148000 / 690827 lineas (21.4%)
# Revisado 148500 / 690827 lineas (21.5%)
# Revisado 149000 / 690827 lineas (21.6%)
# Revisado 149500 / 690827 lineas (21.6%)
# Revisado 150000 / 690827 lineas (21.7%)
#   ...procesadas 150000 filas
# Revisado 150500 / 690827 lineas (21.8%)
# Revisado 151000 / 690827 lineas (21.9%)
# Revisado 151500 / 690827 lineas (21.9%)
# Revisado 152000 / 690827 lineas (22.0%)
# Revisado 152500 / 690827 lineas (22.1%)
# Revisado 153000 / 690827 lineas (22.1%)
# Revisado 153500 / 690827 lineas (22.2%)
# Revisado 154000 / 690827 lineas (22.3%)
# Revisado 154500 / 690827 lineas (22.4%)
# Revisado 155000 / 690827 lineas (22.4%)
# Revisado 155500 / 690827 lineas (22.5%)
# Revisado 156000 / 690827 lineas (22.6%)
# Revisado 156500 / 690827 lineas (22.7%)
# Revisado 157000 / 690827 lineas (22.7%)
# Revisado 157500 / 690827 lineas (22.8%)
# Revisado 158000 / 690827 lineas (22.9%)
# Revisado 158500 / 690827 lineas (22.9%)
# Revisado 159000 / 690827 lineas (23.0%)
# Revisado 159500 / 690827 lineas (23.1%)
# Revisado 160000 / 690827 lineas (23.2%)
#   ...procesadas 160000 filas
# Revisado 160500 / 690827 lineas (23.2%)
# Revisado 161000 / 690827 lineas (23.3%)
# Revisado 161500 / 690827 lineas (23.4%)
# Revisado 162000 / 690827 lineas (23.5%)
# Revisado 162500 / 690827 lineas (23.5%)
# Revisado 163000 / 690827 lineas (23.6%)
# Revisado 163500 / 690827 lineas (23.7%)
# Revisado 164000 / 690827 lineas (23.7%)
# Revisado 164500 / 690827 lineas (23.8%)
# Revisado 165000 / 690827 lineas (23.9%)
# Revisado 165500 / 690827 lineas (24.0%)
# Revisado 166000 / 690827 lineas (24.0%)
# Revisado 166500 / 690827 lineas (24.1%)
# Revisado 167000 / 690827 lineas (24.2%)
# Revisado 167500 / 690827 lineas (24.2%)
# Revisado 168000 / 690827 lineas (24.3%)
# Revisado 168500 / 690827 lineas (24.4%)
# Revisado 169000 / 690827 lineas (24.5%)
# Revisado 169500 / 690827 lineas (24.5%)
# Revisado 170000 / 690827 lineas (24.6%)
#   ...procesadas 170000 filas
# Revisado 170500 / 690827 lineas (24.7%)
# Revisado 171000 / 690827 lineas (24.8%)
# Revisado 171500 / 690827 lineas (24.8%)
# Revisado 172000 / 690827 lineas (24.9%)
# Revisado 172500 / 690827 lineas (25.0%)
# Revisado 173000 / 690827 lineas (25.0%)
# Revisado 173500 / 690827 lineas (25.1%)
# Revisado 174000 / 690827 lineas (25.2%)
# Revisado 174500 / 690827 lineas (25.3%)
# Revisado 175000 / 690827 lineas (25.3%)
# Revisado 175500 / 690827 lineas (25.4%)
# Revisado 176000 / 690827 lineas (25.5%)
# Revisado 176500 / 690827 lineas (25.5%)
# Revisado 177000 / 690827 lineas (25.6%)
# Revisado 177500 / 690827 lineas (25.7%)
# Revisado 178000 / 690827 lineas (25.8%)
# Revisado 178500 / 690827 lineas (25.8%)
# Revisado 179000 / 690827 lineas (25.9%)
# Revisado 179500 / 690827 lineas (26.0%)
# Revisado 180000 / 690827 lineas (26.1%)
#   ...procesadas 180000 filas
# Revisado 180500 / 690827 lineas (26.1%)
# Revisado 181000 / 690827 lineas (26.2%)
# Revisado 181500 / 690827 lineas (26.3%)
# Revisado 182000 / 690827 lineas (26.3%)
# Revisado 182500 / 690827 lineas (26.4%)
# Revisado 183000 / 690827 lineas (26.5%)
# Revisado 183500 / 690827 lineas (26.6%)
# Revisado 184000 / 690827 lineas (26.6%)
# Revisado 184500 / 690827 lineas (26.7%)
# Revisado 185000 / 690827 lineas (26.8%)
# Revisado 185500 / 690827 lineas (26.9%)
# Revisado 186000 / 690827 lineas (26.9%)
# Revisado 186500 / 690827 lineas (27.0%)
# Revisado 187000 / 690827 lineas (27.1%)
# Revisado 187500 / 690827 lineas (27.1%)
# Revisado 188000 / 690827 lineas (27.2%)
# Revisado 188500 / 690827 lineas (27.3%)
# Revisado 189000 / 690827 lineas (27.4%)
# Revisado 189500 / 690827 lineas (27.4%)
# Revisado 190000 / 690827 lineas (27.5%)
#   ...procesadas 190000 filas
# Revisado 190500 / 690827 lineas (27.6%)
# Revisado 191000 / 690827 lineas (27.6%)
# Revisado 191500 / 690827 lineas (27.7%)
# Revisado 192000 / 690827 lineas (27.8%)
# Revisado 192500 / 690827 lineas (27.9%)
# Revisado 193000 / 690827 lineas (27.9%)
# Revisado 193500 / 690827 lineas (28.0%)
# Revisado 194000 / 690827 lineas (28.1%)
# Revisado 194500 / 690827 lineas (28.2%)
# Revisado 195000 / 690827 lineas (28.2%)
# Revisado 195500 / 690827 lineas (28.3%)
# Revisado 196000 / 690827 lineas (28.4%)
# Revisado 196500 / 690827 lineas (28.4%)
# Revisado 197000 / 690827 lineas (28.5%)
# Revisado 197500 / 690827 lineas (28.6%)
# Revisado 198000 / 690827 lineas (28.7%)
# Revisado 198500 / 690827 lineas (28.7%)
# Revisado 199000 / 690827 lineas (28.8%)
# Revisado 199500 / 690827 lineas (28.9%)
# Revisado 200000 / 690827 lineas (29.0%)
#   ...procesadas 200000 filas
# Revisado 200500 / 690827 lineas (29.0%)
# Revisado 201000 / 690827 lineas (29.1%)
# Revisado 201500 / 690827 lineas (29.2%)
# Revisado 202000 / 690827 lineas (29.2%)
# Revisado 202500 / 690827 lineas (29.3%)
# Revisado 203000 / 690827 lineas (29.4%)
# Revisado 203500 / 690827 lineas (29.5%)
# Revisado 204000 / 690827 lineas (29.5%)
# Revisado 204500 / 690827 lineas (29.6%)
# Revisado 205000 / 690827 lineas (29.7%)
# Revisado 205500 / 690827 lineas (29.7%)
# Revisado 206000 / 690827 lineas (29.8%)
# Revisado 206500 / 690827 lineas (29.9%)
# Revisado 207000 / 690827 lineas (30.0%)
# Revisado 207500 / 690827 lineas (30.0%)
# Revisado 208000 / 690827 lineas (30.1%)
# Revisado 208500 / 690827 lineas (30.2%)
# Revisado 209000 / 690827 lineas (30.3%)
# Revisado 209500 / 690827 lineas (30.3%)
# Revisado 210000 / 690827 lineas (30.4%)
#   ...procesadas 210000 filas
# Revisado 210500 / 690827 lineas (30.5%)
# Revisado 211000 / 690827 lineas (30.5%)
# Revisado 211500 / 690827 lineas (30.6%)
# Revisado 212000 / 690827 lineas (30.7%)
# Revisado 212500 / 690827 lineas (30.8%)
# Revisado 213000 / 690827 lineas (30.8%)
# Revisado 213500 / 690827 lineas (30.9%)
# Revisado 214000 / 690827 lineas (31.0%)
# Revisado 214500 / 690827 lineas (31.0%)
# Revisado 215000 / 690827 lineas (31.1%)
# Revisado 215500 / 690827 lineas (31.2%)
# Revisado 216000 / 690827 lineas (31.3%)
# Revisado 216500 / 690827 lineas (31.3%)
# Revisado 217000 / 690827 lineas (31.4%)
# Revisado 217500 / 690827 lineas (31.5%)
# Revisado 218000 / 690827 lineas (31.6%)
# Revisado 218500 / 690827 lineas (31.6%)
# Revisado 219000 / 690827 lineas (31.7%)
# Revisado 219500 / 690827 lineas (31.8%)
# Revisado 220000 / 690827 lineas (31.8%)
#   ...procesadas 220000 filas
# Revisado 220500 / 690827 lineas (31.9%)
# Revisado 221000 / 690827 lineas (32.0%)
# Revisado 221500 / 690827 lineas (32.1%)
# Revisado 222000 / 690827 lineas (32.1%)
# Revisado 222500 / 690827 lineas (32.2%)
# Revisado 223000 / 690827 lineas (32.3%)
# Revisado 223500 / 690827 lineas (32.4%)
# Revisado 224000 / 690827 lineas (32.4%)
# Revisado 224500 / 690827 lineas (32.5%)
# Revisado 225000 / 690827 lineas (32.6%)
# Revisado 225500 / 690827 lineas (32.6%)
# Revisado 226000 / 690827 lineas (32.7%)
# Revisado 226500 / 690827 lineas (32.8%)
# Revisado 227000 / 690827 lineas (32.9%)
# Revisado 227500 / 690827 lineas (32.9%)
# Revisado 228000 / 690827 lineas (33.0%)
# Revisado 228500 / 690827 lineas (33.1%)
# Revisado 229000 / 690827 lineas (33.1%)
# Revisado 229500 / 690827 lineas (33.2%)
# Revisado 230000 / 690827 lineas (33.3%)
#   ...procesadas 230000 filas
# Revisado 230500 / 690827 lineas (33.4%)
# Revisado 231000 / 690827 lineas (33.4%)
# Revisado 231500 / 690827 lineas (33.5%)
# Revisado 232000 / 690827 lineas (33.6%)
# Revisado 232500 / 690827 lineas (33.7%)
# Revisado 233000 / 690827 lineas (33.7%)
# Revisado 233500 / 690827 lineas (33.8%)
# Revisado 234000 / 690827 lineas (33.9%)
# Revisado 234500 / 690827 lineas (33.9%)
# Revisado 235000 / 690827 lineas (34.0%)
# Revisado 235500 / 690827 lineas (34.1%)
# Revisado 236000 / 690827 lineas (34.2%)
# Revisado 236500 / 690827 lineas (34.2%)
# Revisado 237000 / 690827 lineas (34.3%)
# Revisado 237500 / 690827 lineas (34.4%)
# Revisado 238000 / 690827 lineas (34.5%)
# Revisado 238500 / 690827 lineas (34.5%)
# Revisado 239000 / 690827 lineas (34.6%)
# Revisado 239500 / 690827 lineas (34.7%)
# Revisado 240000 / 690827 lineas (34.7%)
#   ...procesadas 240000 filas
# Revisado 240500 / 690827 lineas (34.8%)
# Revisado 241000 / 690827 lineas (34.9%)
# Revisado 241500 / 690827 lineas (35.0%)
# Revisado 242000 / 690827 lineas (35.0%)
# Revisado 242500 / 690827 lineas (35.1%)
# Revisado 243000 / 690827 lineas (35.2%)
# Revisado 243500 / 690827 lineas (35.2%)
# Revisado 244000 / 690827 lineas (35.3%)
# Revisado 244500 / 690827 lineas (35.4%)
# Revisado 245000 / 690827 lineas (35.5%)
# Revisado 245500 / 690827 lineas (35.5%)
# Revisado 246000 / 690827 lineas (35.6%)
# Revisado 246500 / 690827 lineas (35.7%)
# Revisado 247000 / 690827 lineas (35.8%)
# Revisado 247500 / 690827 lineas (35.8%)
# Revisado 248000 / 690827 lineas (35.9%)
# Revisado 248500 / 690827 lineas (36.0%)
# Revisado 249000 / 690827 lineas (36.0%)
# Revisado 249500 / 690827 lineas (36.1%)
# Revisado 250000 / 690827 lineas (36.2%)
#   ...procesadas 250000 filas
# Revisado 250500 / 690827 lineas (36.3%)
# Revisado 251000 / 690827 lineas (36.3%)
# Revisado 251500 / 690827 lineas (36.4%)
# Revisado 252000 / 690827 lineas (36.5%)
# Revisado 252500 / 690827 lineas (36.6%)
# Revisado 253000 / 690827 lineas (36.6%)
# Revisado 253500 / 690827 lineas (36.7%)
# Revisado 254000 / 690827 lineas (36.8%)
# Revisado 254500 / 690827 lineas (36.8%)
# Revisado 255000 / 690827 lineas (36.9%)
# Revisado 255500 / 690827 lineas (37.0%)
# Revisado 256000 / 690827 lineas (37.1%)
# Revisado 256500 / 690827 lineas (37.1%)
# Revisado 257000 / 690827 lineas (37.2%)
# Revisado 257500 / 690827 lineas (37.3%)
# Revisado 258000 / 690827 lineas (37.3%)
# Revisado 258500 / 690827 lineas (37.4%)
# Revisado 259000 / 690827 lineas (37.5%)
# Revisado 259500 / 690827 lineas (37.6%)
# Revisado 260000 / 690827 lineas (37.6%)
#   ...procesadas 260000 filas
# Revisado 260500 / 690827 lineas (37.7%)
# Revisado 261000 / 690827 lineas (37.8%)
# Revisado 261500 / 690827 lineas (37.9%)
# Revisado 262000 / 690827 lineas (37.9%)
# Revisado 262500 / 690827 lineas (38.0%)
# Revisado 263000 / 690827 lineas (38.1%)
# Revisado 263500 / 690827 lineas (38.1%)
# Revisado 264000 / 690827 lineas (38.2%)
# Revisado 264500 / 690827 lineas (38.3%)
# Revisado 265000 / 690827 lineas (38.4%)
# Revisado 265500 / 690827 lineas (38.4%)
# Revisado 266000 / 690827 lineas (38.5%)
# Revisado 266500 / 690827 lineas (38.6%)
# Revisado 267000 / 690827 lineas (38.6%)
# Revisado 267500 / 690827 lineas (38.7%)
# Revisado 268000 / 690827 lineas (38.8%)
# Revisado 268500 / 690827 lineas (38.9%)
# Revisado 269000 / 690827 lineas (38.9%)
# Revisado 269500 / 690827 lineas (39.0%)
# Revisado 270000 / 690827 lineas (39.1%)
#   ...procesadas 270000 filas
# Revisado 270500 / 690827 lineas (39.2%)
# Revisado 271000 / 690827 lineas (39.2%)
# Revisado 271500 / 690827 lineas (39.3%)
# Revisado 272000 / 690827 lineas (39.4%)
# Revisado 272500 / 690827 lineas (39.4%)
# Revisado 273000 / 690827 lineas (39.5%)
# Revisado 273500 / 690827 lineas (39.6%)
# Revisado 274000 / 690827 lineas (39.7%)
# Revisado 274500 / 690827 lineas (39.7%)
# Revisado 275000 / 690827 lineas (39.8%)
# Revisado 275500 / 690827 lineas (39.9%)
# Revisado 276000 / 690827 lineas (40.0%)
# Revisado 276500 / 690827 lineas (40.0%)
# Revisado 277000 / 690827 lineas (40.1%)
# Revisado 277500 / 690827 lineas (40.2%)
# Revisado 278000 / 690827 lineas (40.2%)
# Revisado 278500 / 690827 lineas (40.3%)
# Revisado 279000 / 690827 lineas (40.4%)
# Revisado 279500 / 690827 lineas (40.5%)
# Revisado 280000 / 690827 lineas (40.5%)
#   ...procesadas 280000 filas
# Revisado 280500 / 690827 lineas (40.6%)
# Revisado 281000 / 690827 lineas (40.7%)
# Revisado 281500 / 690827 lineas (40.7%)
# Revisado 282000 / 690827 lineas (40.8%)
# Revisado 282500 / 690827 lineas (40.9%)
# Revisado 283000 / 690827 lineas (41.0%)
# Revisado 283500 / 690827 lineas (41.0%)
# Revisado 284000 / 690827 lineas (41.1%)
# Revisado 284500 / 690827 lineas (41.2%)
# Revisado 285000 / 690827 lineas (41.3%)
# Revisado 285500 / 690827 lineas (41.3%)
# Revisado 286000 / 690827 lineas (41.4%)
# Revisado 286500 / 690827 lineas (41.5%)
# Revisado 287000 / 690827 lineas (41.5%)
# Revisado 287500 / 690827 lineas (41.6%)
# Revisado 288000 / 690827 lineas (41.7%)
# Revisado 288500 / 690827 lineas (41.8%)
# Revisado 289000 / 690827 lineas (41.8%)
# Revisado 289500 / 690827 lineas (41.9%)
# Revisado 290000 / 690827 lineas (42.0%)
#   ...procesadas 290000 filas
# Revisado 290500 / 690827 lineas (42.1%)
# Revisado 291000 / 690827 lineas (42.1%)
# Revisado 291500 / 690827 lineas (42.2%)
# Revisado 292000 / 690827 lineas (42.3%)
# Revisado 292500 / 690827 lineas (42.3%)
# Revisado 293000 / 690827 lineas (42.4%)
# Revisado 293500 / 690827 lineas (42.5%)
# Revisado 294000 / 690827 lineas (42.6%)
# Revisado 294500 / 690827 lineas (42.6%)
# Revisado 295000 / 690827 lineas (42.7%)
# Revisado 295500 / 690827 lineas (42.8%)
# Revisado 296000 / 690827 lineas (42.8%)
# Revisado 296500 / 690827 lineas (42.9%)
# Revisado 297000 / 690827 lineas (43.0%)
# Revisado 297500 / 690827 lineas (43.1%)
# Revisado 298000 / 690827 lineas (43.1%)
# Revisado 298500 / 690827 lineas (43.2%)
# Revisado 299000 / 690827 lineas (43.3%)
# Revisado 299500 / 690827 lineas (43.4%)
# Revisado 300000 / 690827 lineas (43.4%)
#   ...procesadas 300000 filas
# Revisado 300500 / 690827 lineas (43.5%)
# Revisado 301000 / 690827 lineas (43.6%)
# Revisado 301500 / 690827 lineas (43.6%)
# Revisado 302000 / 690827 lineas (43.7%)
# Revisado 302500 / 690827 lineas (43.8%)
# Revisado 303000 / 690827 lineas (43.9%)
# Revisado 303500 / 690827 lineas (43.9%)
# Revisado 304000 / 690827 lineas (44.0%)
# Revisado 304500 / 690827 lineas (44.1%)
# Revisado 305000 / 690827 lineas (44.1%)
# Revisado 305500 / 690827 lineas (44.2%)
# Revisado 306000 / 690827 lineas (44.3%)
# Revisado 306500 / 690827 lineas (44.4%)
# Revisado 307000 / 690827 lineas (44.4%)
# Revisado 307500 / 690827 lineas (44.5%)
# Revisado 308000 / 690827 lineas (44.6%)
# Revisado 308500 / 690827 lineas (44.7%)
# Revisado 309000 / 690827 lineas (44.7%)
# Revisado 309500 / 690827 lineas (44.8%)
# Revisado 310000 / 690827 lineas (44.9%)
#   ...procesadas 310000 filas
# Revisado 310500 / 690827 lineas (44.9%)
# Revisado 311000 / 690827 lineas (45.0%)
# Revisado 311500 / 690827 lineas (45.1%)
# Revisado 312000 / 690827 lineas (45.2%)
# Revisado 312500 / 690827 lineas (45.2%)
# Revisado 313000 / 690827 lineas (45.3%)
# Revisado 313500 / 690827 lineas (45.4%)
# Revisado 314000 / 690827 lineas (45.5%)
# Revisado 314500 / 690827 lineas (45.5%)
# Revisado 315000 / 690827 lineas (45.6%)
# Revisado 315500 / 690827 lineas (45.7%)
# Revisado 316000 / 690827 lineas (45.7%)
# Revisado 316500 / 690827 lineas (45.8%)
# Revisado 317000 / 690827 lineas (45.9%)
# Revisado 317500 / 690827 lineas (46.0%)
# Revisado 318000 / 690827 lineas (46.0%)
# Revisado 318500 / 690827 lineas (46.1%)
# Revisado 319000 / 690827 lineas (46.2%)
# Revisado 319500 / 690827 lineas (46.2%)
# Revisado 320000 / 690827 lineas (46.3%)
#   ...procesadas 320000 filas
# Revisado 320500 / 690827 lineas (46.4%)
# Revisado 321000 / 690827 lineas (46.5%)
# Revisado 321500 / 690827 lineas (46.5%)
# Revisado 322000 / 690827 lineas (46.6%)
# Revisado 322500 / 690827 lineas (46.7%)
# Revisado 323000 / 690827 lineas (46.8%)
# Revisado 323500 / 690827 lineas (46.8%)
# Revisado 324000 / 690827 lineas (46.9%)
# Revisado 324500 / 690827 lineas (47.0%)
# Revisado 325000 / 690827 lineas (47.0%)
# Revisado 325500 / 690827 lineas (47.1%)
# Revisado 326000 / 690827 lineas (47.2%)
# Revisado 326500 / 690827 lineas (47.3%)
# Revisado 327000 / 690827 lineas (47.3%)
# Revisado 327500 / 690827 lineas (47.4%)
# Revisado 328000 / 690827 lineas (47.5%)
# Revisado 328500 / 690827 lineas (47.6%)
# Revisado 329000 / 690827 lineas (47.6%)
# Revisado 329500 / 690827 lineas (47.7%)
# Revisado 330000 / 690827 lineas (47.8%)
#   ...procesadas 330000 filas
# Revisado 330500 / 690827 lineas (47.8%)
# Revisado 331000 / 690827 lineas (47.9%)
# Revisado 331500 / 690827 lineas (48.0%)
# Revisado 332000 / 690827 lineas (48.1%)
# Revisado 332500 / 690827 lineas (48.1%)
# Revisado 333000 / 690827 lineas (48.2%)
# Revisado 333500 / 690827 lineas (48.3%)
# Revisado 334000 / 690827 lineas (48.3%)
# Revisado 334500 / 690827 lineas (48.4%)
# Revisado 335000 / 690827 lineas (48.5%)
# Revisado 335500 / 690827 lineas (48.6%)
# Revisado 336000 / 690827 lineas (48.6%)
# Revisado 336500 / 690827 lineas (48.7%)
# Revisado 337000 / 690827 lineas (48.8%)
# Revisado 337500 / 690827 lineas (48.9%)
# Revisado 338000 / 690827 lineas (48.9%)
# Revisado 338500 / 690827 lineas (49.0%)
# Revisado 339000 / 690827 lineas (49.1%)
# Revisado 339500 / 690827 lineas (49.1%)
# Revisado 340000 / 690827 lineas (49.2%)
#   ...procesadas 340000 filas
# Revisado 340500 / 690827 lineas (49.3%)
# Revisado 341000 / 690827 lineas (49.4%)
# Revisado 341500 / 690827 lineas (49.4%)
# Revisado 342000 / 690827 lineas (49.5%)
# Revisado 342500 / 690827 lineas (49.6%)
# Revisado 343000 / 690827 lineas (49.7%)
# Revisado 343500 / 690827 lineas (49.7%)
# Revisado 344000 / 690827 lineas (49.8%)
# Revisado 344500 / 690827 lineas (49.9%)
# Revisado 345000 / 690827 lineas (49.9%)
# Revisado 345500 / 690827 lineas (50.0%)
# Revisado 346000 / 690827 lineas (50.1%)
# Revisado 346500 / 690827 lineas (50.2%)
# Revisado 347000 / 690827 lineas (50.2%)
# Revisado 347500 / 690827 lineas (50.3%)
# Revisado 348000 / 690827 lineas (50.4%)
# Revisado 348500 / 690827 lineas (50.4%)
# Revisado 349000 / 690827 lineas (50.5%)
# Revisado 349500 / 690827 lineas (50.6%)
# Revisado 350000 / 690827 lineas (50.7%)
#   ...procesadas 350000 filas
# Revisado 350500 / 690827 lineas (50.7%)
# Revisado 351000 / 690827 lineas (50.8%)
# Revisado 351500 / 690827 lineas (50.9%)
# Revisado 352000 / 690827 lineas (51.0%)
# Revisado 352500 / 690827 lineas (51.0%)
# Revisado 353000 / 690827 lineas (51.1%)
# Revisado 353500 / 690827 lineas (51.2%)
# Revisado 354000 / 690827 lineas (51.2%)
# Revisado 354500 / 690827 lineas (51.3%)
# Revisado 355000 / 690827 lineas (51.4%)
# Revisado 355500 / 690827 lineas (51.5%)
# Revisado 356000 / 690827 lineas (51.5%)
# Revisado 356500 / 690827 lineas (51.6%)
# Revisado 357000 / 690827 lineas (51.7%)
# Revisado 357500 / 690827 lineas (51.7%)
# Revisado 358000 / 690827 lineas (51.8%)
# Revisado 358500 / 690827 lineas (51.9%)
# Revisado 359000 / 690827 lineas (52.0%)
# Revisado 359500 / 690827 lineas (52.0%)
# Revisado 360000 / 690827 lineas (52.1%)
#   ...procesadas 360000 filas
# Revisado 360500 / 690827 lineas (52.2%)
# Revisado 361000 / 690827 lineas (52.3%)
# Revisado 361500 / 690827 lineas (52.3%)
# Revisado 362000 / 690827 lineas (52.4%)
# Revisado 362500 / 690827 lineas (52.5%)
# Revisado 363000 / 690827 lineas (52.5%)
# Revisado 363500 / 690827 lineas (52.6%)
# Revisado 364000 / 690827 lineas (52.7%)
# Revisado 364500 / 690827 lineas (52.8%)
# Revisado 365000 / 690827 lineas (52.8%)
# Revisado 365500 / 690827 lineas (52.9%)
# Revisado 366000 / 690827 lineas (53.0%)
# Revisado 366500 / 690827 lineas (53.1%)
# Revisado 367000 / 690827 lineas (53.1%)
# Revisado 367500 / 690827 lineas (53.2%)
# Revisado 368000 / 690827 lineas (53.3%)
# Revisado 368500 / 690827 lineas (53.3%)
# Revisado 369000 / 690827 lineas (53.4%)
# Revisado 369500 / 690827 lineas (53.5%)
# Revisado 370000 / 690827 lineas (53.6%)
#   ...procesadas 370000 filas
# Revisado 370500 / 690827 lineas (53.6%)
# Revisado 371000 / 690827 lineas (53.7%)
# Revisado 371500 / 690827 lineas (53.8%)
# Revisado 372000 / 690827 lineas (53.8%)
# Revisado 372500 / 690827 lineas (53.9%)
# Revisado 373000 / 690827 lineas (54.0%)
# Revisado 373500 / 690827 lineas (54.1%)
# Revisado 374000 / 690827 lineas (54.1%)
# Revisado 374500 / 690827 lineas (54.2%)
# Revisado 375000 / 690827 lineas (54.3%)
# Revisado 375500 / 690827 lineas (54.4%)
# Revisado 376000 / 690827 lineas (54.4%)
# Revisado 376500 / 690827 lineas (54.5%)
# Revisado 377000 / 690827 lineas (54.6%)
# Revisado 377500 / 690827 lineas (54.6%)
# Revisado 378000 / 690827 lineas (54.7%)
# Revisado 378500 / 690827 lineas (54.8%)
# Revisado 379000 / 690827 lineas (54.9%)
# Revisado 379500 / 690827 lineas (54.9%)
# Revisado 380000 / 690827 lineas (55.0%)
#   ...procesadas 380000 filas
# Revisado 380500 / 690827 lineas (55.1%)
# Revisado 381000 / 690827 lineas (55.2%)
# Revisado 381500 / 690827 lineas (55.2%)
# Revisado 382000 / 690827 lineas (55.3%)
# Revisado 382500 / 690827 lineas (55.4%)
# Revisado 383000 / 690827 lineas (55.4%)
# Revisado 383500 / 690827 lineas (55.5%)
# Revisado 384000 / 690827 lineas (55.6%)
# Revisado 384500 / 690827 lineas (55.7%)
# Revisado 385000 / 690827 lineas (55.7%)
# Revisado 385500 / 690827 lineas (55.8%)
# Revisado 386000 / 690827 lineas (55.9%)
# Revisado 386500 / 690827 lineas (55.9%)
# Revisado 387000 / 690827 lineas (56.0%)
# Revisado 387500 / 690827 lineas (56.1%)
# Revisado 388000 / 690827 lineas (56.2%)
# Revisado 388500 / 690827 lineas (56.2%)
# Revisado 389000 / 690827 lineas (56.3%)
# Revisado 389500 / 690827 lineas (56.4%)
# Revisado 390000 / 690827 lineas (56.5%)
#   ...procesadas 390000 filas
# Revisado 390500 / 690827 lineas (56.5%)
# Revisado 391000 / 690827 lineas (56.6%)
# Revisado 391500 / 690827 lineas (56.7%)
# Revisado 392000 / 690827 lineas (56.7%)
# Revisado 392500 / 690827 lineas (56.8%)
# Revisado 393000 / 690827 lineas (56.9%)
# Revisado 393500 / 690827 lineas (57.0%)
# Revisado 394000 / 690827 lineas (57.0%)
# Revisado 394500 / 690827 lineas (57.1%)
# Revisado 395000 / 690827 lineas (57.2%)
# Revisado 395500 / 690827 lineas (57.3%)
# Revisado 396000 / 690827 lineas (57.3%)
# Revisado 396500 / 690827 lineas (57.4%)
# Revisado 397000 / 690827 lineas (57.5%)
# Revisado 397500 / 690827 lineas (57.5%)
# Revisado 398000 / 690827 lineas (57.6%)
# Revisado 398500 / 690827 lineas (57.7%)
# Revisado 399000 / 690827 lineas (57.8%)
# Revisado 399500 / 690827 lineas (57.8%)
# Revisado 400000 / 690827 lineas (57.9%)
#   ...procesadas 400000 filas
# Revisado 400500 / 690827 lineas (58.0%)
# Revisado 401000 / 690827 lineas (58.0%)
# Revisado 401500 / 690827 lineas (58.1%)
# Revisado 402000 / 690827 lineas (58.2%)
# Revisado 402500 / 690827 lineas (58.3%)
# Revisado 403000 / 690827 lineas (58.3%)
# Revisado 403500 / 690827 lineas (58.4%)
# Revisado 404000 / 690827 lineas (58.5%)
# Revisado 404500 / 690827 lineas (58.6%)
# Revisado 405000 / 690827 lineas (58.6%)
# Revisado 405500 / 690827 lineas (58.7%)
# Revisado 406000 / 690827 lineas (58.8%)
# Revisado 406500 / 690827 lineas (58.8%)
# Revisado 407000 / 690827 lineas (58.9%)
# Revisado 407500 / 690827 lineas (59.0%)
# Revisado 408000 / 690827 lineas (59.1%)
# Revisado 408500 / 690827 lineas (59.1%)
# Revisado 409000 / 690827 lineas (59.2%)
# Revisado 409500 / 690827 lineas (59.3%)
# Revisado 410000 / 690827 lineas (59.3%)
#   ...procesadas 410000 filas
# Revisado 410500 / 690827 lineas (59.4%)
# Revisado 411000 / 690827 lineas (59.5%)
# Revisado 411500 / 690827 lineas (59.6%)
# Revisado 412000 / 690827 lineas (59.6%)
# Revisado 412500 / 690827 lineas (59.7%)
# Revisado 413000 / 690827 lineas (59.8%)
# Revisado 413500 / 690827 lineas (59.9%)
# Revisado 414000 / 690827 lineas (59.9%)
# Revisado 414500 / 690827 lineas (60.0%)
# Revisado 415000 / 690827 lineas (60.1%)
# Revisado 415500 / 690827 lineas (60.1%)
# Revisado 416000 / 690827 lineas (60.2%)
# Revisado 416500 / 690827 lineas (60.3%)
# Revisado 417000 / 690827 lineas (60.4%)
# Revisado 417500 / 690827 lineas (60.4%)
# Revisado 418000 / 690827 lineas (60.5%)
# Revisado 418500 / 690827 lineas (60.6%)
# Revisado 419000 / 690827 lineas (60.7%)
# Revisado 419500 / 690827 lineas (60.7%)
# Revisado 420000 / 690827 lineas (60.8%)
#   ...procesadas 420000 filas
# Revisado 420500 / 690827 lineas (60.9%)
# Revisado 421000 / 690827 lineas (60.9%)
# Revisado 421500 / 690827 lineas (61.0%)
# Revisado 422000 / 690827 lineas (61.1%)
# Revisado 422500 / 690827 lineas (61.2%)
# Revisado 423000 / 690827 lineas (61.2%)
# Revisado 423500 / 690827 lineas (61.3%)
# Revisado 424000 / 690827 lineas (61.4%)
# Revisado 424500 / 690827 lineas (61.4%)
# Revisado 425000 / 690827 lineas (61.5%)
# Revisado 425500 / 690827 lineas (61.6%)
# Revisado 426000 / 690827 lineas (61.7%)
# Revisado 426500 / 690827 lineas (61.7%)
# Revisado 427000 / 690827 lineas (61.8%)
# Revisado 427500 / 690827 lineas (61.9%)
# Revisado 428000 / 690827 lineas (62.0%)
# Revisado 428500 / 690827 lineas (62.0%)
# Revisado 429000 / 690827 lineas (62.1%)
# Revisado 429500 / 690827 lineas (62.2%)
# Revisado 430000 / 690827 lineas (62.2%)
#   ...procesadas 430000 filas
# Revisado 430500 / 690827 lineas (62.3%)
# Revisado 431000 / 690827 lineas (62.4%)
# Revisado 431500 / 690827 lineas (62.5%)
# Revisado 432000 / 690827 lineas (62.5%)
# Revisado 432500 / 690827 lineas (62.6%)
# Revisado 433000 / 690827 lineas (62.7%)
# Revisado 433500 / 690827 lineas (62.8%)
# Revisado 434000 / 690827 lineas (62.8%)
# Revisado 434500 / 690827 lineas (62.9%)
# Revisado 435000 / 690827 lineas (63.0%)
# Revisado 435500 / 690827 lineas (63.0%)
# Revisado 436000 / 690827 lineas (63.1%)
# Revisado 436500 / 690827 lineas (63.2%)
# Revisado 437000 / 690827 lineas (63.3%)
# Revisado 437500 / 690827 lineas (63.3%)
# Revisado 438000 / 690827 lineas (63.4%)
# Revisado 438500 / 690827 lineas (63.5%)
# Revisado 439000 / 690827 lineas (63.5%)
# Revisado 439500 / 690827 lineas (63.6%)
# Revisado 440000 / 690827 lineas (63.7%)
#   ...procesadas 440000 filas
# Revisado 440500 / 690827 lineas (63.8%)
# Revisado 441000 / 690827 lineas (63.8%)
# Revisado 441500 / 690827 lineas (63.9%)
# Revisado 442000 / 690827 lineas (64.0%)
# Revisado 442500 / 690827 lineas (64.1%)
# Revisado 443000 / 690827 lineas (64.1%)
# Revisado 443500 / 690827 lineas (64.2%)
# Revisado 444000 / 690827 lineas (64.3%)
# Revisado 444500 / 690827 lineas (64.3%)
# Revisado 445000 / 690827 lineas (64.4%)
# Revisado 445500 / 690827 lineas (64.5%)
# Revisado 446000 / 690827 lineas (64.6%)
# Revisado 446500 / 690827 lineas (64.6%)
# Revisado 447000 / 690827 lineas (64.7%)
# Revisado 447500 / 690827 lineas (64.8%)
# Revisado 448000 / 690827 lineas (64.8%)
# Revisado 448500 / 690827 lineas (64.9%)
# Revisado 449000 / 690827 lineas (65.0%)
# Revisado 449500 / 690827 lineas (65.1%)
# Revisado 450000 / 690827 lineas (65.1%)
#   ...procesadas 450000 filas
# Revisado 450500 / 690827 lineas (65.2%)
# Revisado 451000 / 690827 lineas (65.3%)
# Revisado 451500 / 690827 lineas (65.4%)
# Revisado 452000 / 690827 lineas (65.4%)
# Revisado 452500 / 690827 lineas (65.5%)
# Revisado 453000 / 690827 lineas (65.6%)
# Revisado 453500 / 690827 lineas (65.6%)
# Revisado 454000 / 690827 lineas (65.7%)
# Revisado 454500 / 690827 lineas (65.8%)
# Revisado 455000 / 690827 lineas (65.9%)
# Revisado 455500 / 690827 lineas (65.9%)
# Revisado 456000 / 690827 lineas (66.0%)
# Revisado 456500 / 690827 lineas (66.1%)
# Revisado 457000 / 690827 lineas (66.2%)
# Revisado 457500 / 690827 lineas (66.2%)
# Revisado 458000 / 690827 lineas (66.3%)
# Revisado 458500 / 690827 lineas (66.4%)
# Revisado 459000 / 690827 lineas (66.4%)
# Revisado 459500 / 690827 lineas (66.5%)
# Revisado 460000 / 690827 lineas (66.6%)
#   ...procesadas 460000 filas
# Revisado 460500 / 690827 lineas (66.7%)
# Revisado 461000 / 690827 lineas (66.7%)
# Revisado 461500 / 690827 lineas (66.8%)
# Revisado 462000 / 690827 lineas (66.9%)
# Revisado 462500 / 690827 lineas (66.9%)
# Revisado 463000 / 690827 lineas (67.0%)
# Revisado 463500 / 690827 lineas (67.1%)
# Revisado 464000 / 690827 lineas (67.2%)
# Revisado 464500 / 690827 lineas (67.2%)
# Revisado 465000 / 690827 lineas (67.3%)
# Revisado 465500 / 690827 lineas (67.4%)
# Revisado 466000 / 690827 lineas (67.5%)
# Revisado 466500 / 690827 lineas (67.5%)
# Revisado 467000 / 690827 lineas (67.6%)
# Revisado 467500 / 690827 lineas (67.7%)
# Revisado 468000 / 690827 lineas (67.7%)
# Revisado 468500 / 690827 lineas (67.8%)
# Revisado 469000 / 690827 lineas (67.9%)
# Revisado 469500 / 690827 lineas (68.0%)
# Revisado 470000 / 690827 lineas (68.0%)
#   ...procesadas 470000 filas
# Revisado 470500 / 690827 lineas (68.1%)
# Revisado 471000 / 690827 lineas (68.2%)
# Revisado 471500 / 690827 lineas (68.3%)
# Revisado 472000 / 690827 lineas (68.3%)
# Revisado 472500 / 690827 lineas (68.4%)
# Revisado 473000 / 690827 lineas (68.5%)
# Revisado 473500 / 690827 lineas (68.5%)
# Revisado 474000 / 690827 lineas (68.6%)
# Revisado 474500 / 690827 lineas (68.7%)
# Revisado 475000 / 690827 lineas (68.8%)
# Revisado 475500 / 690827 lineas (68.8%)
# Revisado 476000 / 690827 lineas (68.9%)
# Revisado 476500 / 690827 lineas (69.0%)
# Revisado 477000 / 690827 lineas (69.0%)
# Revisado 477500 / 690827 lineas (69.1%)
# Revisado 478000 / 690827 lineas (69.2%)
# Revisado 478500 / 690827 lineas (69.3%)
# Revisado 479000 / 690827 lineas (69.3%)
# Revisado 479500 / 690827 lineas (69.4%)
# Revisado 480000 / 690827 lineas (69.5%)
#   ...procesadas 480000 filas
# Revisado 480500 / 690827 lineas (69.6%)
# Revisado 481000 / 690827 lineas (69.6%)
# Revisado 481500 / 690827 lineas (69.7%)
# Revisado 482000 / 690827 lineas (69.8%)
# Revisado 482500 / 690827 lineas (69.8%)
# Revisado 483000 / 690827 lineas (69.9%)
# Revisado 483500 / 690827 lineas (70.0%)
# Revisado 484000 / 690827 lineas (70.1%)
# Revisado 484500 / 690827 lineas (70.1%)
# Revisado 485000 / 690827 lineas (70.2%)
# Revisado 485500 / 690827 lineas (70.3%)
# Revisado 486000 / 690827 lineas (70.4%)
# Revisado 486500 / 690827 lineas (70.4%)
# Revisado 487000 / 690827 lineas (70.5%)
# Revisado 487500 / 690827 lineas (70.6%)
# Revisado 488000 / 690827 lineas (70.6%)
# Revisado 488500 / 690827 lineas (70.7%)
# Revisado 489000 / 690827 lineas (70.8%)
# Revisado 489500 / 690827 lineas (70.9%)
# Revisado 490000 / 690827 lineas (70.9%)
#   ...procesadas 490000 filas
# Revisado 490500 / 690827 lineas (71.0%)
# Revisado 491000 / 690827 lineas (71.1%)
# Revisado 491500 / 690827 lineas (71.1%)
# Revisado 492000 / 690827 lineas (71.2%)
# Revisado 492500 / 690827 lineas (71.3%)
# Revisado 493000 / 690827 lineas (71.4%)
# Revisado 493500 / 690827 lineas (71.4%)
# Revisado 494000 / 690827 lineas (71.5%)
# Revisado 494500 / 690827 lineas (71.6%)
# Revisado 495000 / 690827 lineas (71.7%)
# Revisado 495500 / 690827 lineas (71.7%)
# Revisado 496000 / 690827 lineas (71.8%)
# Revisado 496500 / 690827 lineas (71.9%)
# Revisado 497000 / 690827 lineas (71.9%)
# Revisado 497500 / 690827 lineas (72.0%)
# Revisado 498000 / 690827 lineas (72.1%)
# Revisado 498500 / 690827 lineas (72.2%)
# Revisado 499000 / 690827 lineas (72.2%)
# Revisado 499500 / 690827 lineas (72.3%)
# Revisado 500000 / 690827 lineas (72.4%)
#   ...procesadas 500000 filas
# Revisado 500500 / 690827 lineas (72.4%)
# Revisado 501000 / 690827 lineas (72.5%)
# Revisado 501500 / 690827 lineas (72.6%)
# Revisado 502000 / 690827 lineas (72.7%)
# Revisado 502500 / 690827 lineas (72.7%)
# Revisado 503000 / 690827 lineas (72.8%)
# Revisado 503500 / 690827 lineas (72.9%)
# Revisado 504000 / 690827 lineas (73.0%)
# Revisado 504500 / 690827 lineas (73.0%)
# Revisado 505000 / 690827 lineas (73.1%)
# Revisado 505500 / 690827 lineas (73.2%)
# Revisado 506000 / 690827 lineas (73.2%)
# Revisado 506500 / 690827 lineas (73.3%)
# Revisado 507000 / 690827 lineas (73.4%)
# Revisado 507500 / 690827 lineas (73.5%)
# Revisado 508000 / 690827 lineas (73.5%)
# Revisado 508500 / 690827 lineas (73.6%)
# Revisado 509000 / 690827 lineas (73.7%)
# Revisado 509500 / 690827 lineas (73.8%)
# Revisado 510000 / 690827 lineas (73.8%)
#   ...procesadas 510000 filas
# Revisado 510500 / 690827 lineas (73.9%)
# Revisado 511000 / 690827 lineas (74.0%)
# Revisado 511500 / 690827 lineas (74.0%)
# Revisado 512000 / 690827 lineas (74.1%)
# Revisado 512500 / 690827 lineas (74.2%)
# Revisado 513000 / 690827 lineas (74.3%)
# Revisado 513500 / 690827 lineas (74.3%)
# Revisado 514000 / 690827 lineas (74.4%)
# Revisado 514500 / 690827 lineas (74.5%)
# Revisado 515000 / 690827 lineas (74.5%)
# Revisado 515500 / 690827 lineas (74.6%)
# Revisado 516000 / 690827 lineas (74.7%)
# Revisado 516500 / 690827 lineas (74.8%)
# Revisado 517000 / 690827 lineas (74.8%)
# Revisado 517500 / 690827 lineas (74.9%)
# Revisado 518000 / 690827 lineas (75.0%)
# Revisado 518500 / 690827 lineas (75.1%)
# Revisado 519000 / 690827 lineas (75.1%)
# Revisado 519500 / 690827 lineas (75.2%)
# Revisado 520000 / 690827 lineas (75.3%)
#   ...procesadas 520000 filas
# Revisado 520500 / 690827 lineas (75.3%)
# Revisado 521000 / 690827 lineas (75.4%)
# Revisado 521500 / 690827 lineas (75.5%)
# Revisado 522000 / 690827 lineas (75.6%)
# Revisado 522500 / 690827 lineas (75.6%)
# Revisado 523000 / 690827 lineas (75.7%)
# Revisado 523500 / 690827 lineas (75.8%)
# Revisado 524000 / 690827 lineas (75.9%)
# Revisado 524500 / 690827 lineas (75.9%)
# Revisado 525000 / 690827 lineas (76.0%)
# Revisado 525500 / 690827 lineas (76.1%)
# Revisado 526000 / 690827 lineas (76.1%)
# Revisado 526500 / 690827 lineas (76.2%)
# Revisado 527000 / 690827 lineas (76.3%)
# Revisado 527500 / 690827 lineas (76.4%)
# Revisado 528000 / 690827 lineas (76.4%)
# Revisado 528500 / 690827 lineas (76.5%)
# Revisado 529000 / 690827 lineas (76.6%)
# Revisado 529500 / 690827 lineas (76.6%)
# Revisado 530000 / 690827 lineas (76.7%)
#   ...procesadas 530000 filas
# Revisado 530500 / 690827 lineas (76.8%)
# Revisado 531000 / 690827 lineas (76.9%)
# Revisado 531500 / 690827 lineas (76.9%)
# Revisado 532000 / 690827 lineas (77.0%)
# Revisado 532500 / 690827 lineas (77.1%)
# Revisado 533000 / 690827 lineas (77.2%)
# Revisado 533500 / 690827 lineas (77.2%)
# Revisado 534000 / 690827 lineas (77.3%)
# Revisado 534500 / 690827 lineas (77.4%)
# Revisado 535000 / 690827 lineas (77.4%)
# Revisado 535500 / 690827 lineas (77.5%)
# Revisado 536000 / 690827 lineas (77.6%)
# Revisado 536500 / 690827 lineas (77.7%)
# Revisado 537000 / 690827 lineas (77.7%)
# Revisado 537500 / 690827 lineas (77.8%)
# Revisado 538000 / 690827 lineas (77.9%)
# Revisado 538500 / 690827 lineas (78.0%)
# Revisado 539000 / 690827 lineas (78.0%)
# Revisado 539500 / 690827 lineas (78.1%)
# Revisado 540000 / 690827 lineas (78.2%)
#   ...procesadas 540000 filas
# Revisado 540500 / 690827 lineas (78.2%)
# Revisado 541000 / 690827 lineas (78.3%)
# Revisado 541500 / 690827 lineas (78.4%)
# Revisado 542000 / 690827 lineas (78.5%)
# Revisado 542500 / 690827 lineas (78.5%)
# Revisado 543000 / 690827 lineas (78.6%)
# Revisado 543500 / 690827 lineas (78.7%)
# Revisado 544000 / 690827 lineas (78.7%)
# Revisado 544500 / 690827 lineas (78.8%)
# Revisado 545000 / 690827 lineas (78.9%)
# Revisado 545500 / 690827 lineas (79.0%)
# Revisado 546000 / 690827 lineas (79.0%)
# Revisado 546500 / 690827 lineas (79.1%)
# Revisado 547000 / 690827 lineas (79.2%)
# Revisado 547500 / 690827 lineas (79.3%)
# Revisado 548000 / 690827 lineas (79.3%)
# Revisado 548500 / 690827 lineas (79.4%)
# Revisado 549000 / 690827 lineas (79.5%)
# Revisado 549500 / 690827 lineas (79.5%)
# Revisado 550000 / 690827 lineas (79.6%)
#   ...procesadas 550000 filas
# Revisado 550500 / 690827 lineas (79.7%)
# Revisado 551000 / 690827 lineas (79.8%)
# Revisado 551500 / 690827 lineas (79.8%)
# Revisado 552000 / 690827 lineas (79.9%)
# Revisado 552500 / 690827 lineas (80.0%)
# Revisado 553000 / 690827 lineas (80.0%)
# Revisado 553500 / 690827 lineas (80.1%)
# Revisado 554000 / 690827 lineas (80.2%)
# Revisado 554500 / 690827 lineas (80.3%)
# Revisado 555000 / 690827 lineas (80.3%)
# Revisado 555500 / 690827 lineas (80.4%)
# Revisado 556000 / 690827 lineas (80.5%)
# Revisado 556500 / 690827 lineas (80.6%)
# Revisado 557000 / 690827 lineas (80.6%)
# Revisado 557500 / 690827 lineas (80.7%)
# Revisado 558000 / 690827 lineas (80.8%)
# Revisado 558500 / 690827 lineas (80.8%)
# Revisado 559000 / 690827 lineas (80.9%)
# Revisado 559500 / 690827 lineas (81.0%)
# Revisado 560000 / 690827 lineas (81.1%)
#   ...procesadas 560000 filas
# Revisado 560500 / 690827 lineas (81.1%)
# Revisado 561000 / 690827 lineas (81.2%)
# Revisado 561500 / 690827 lineas (81.3%)
# Revisado 562000 / 690827 lineas (81.4%)
# Revisado 562500 / 690827 lineas (81.4%)
# Revisado 563000 / 690827 lineas (81.5%)
# Revisado 563500 / 690827 lineas (81.6%)
# Revisado 564000 / 690827 lineas (81.6%)
# Revisado 564500 / 690827 lineas (81.7%)
# Revisado 565000 / 690827 lineas (81.8%)
# Revisado 565500 / 690827 lineas (81.9%)
# Revisado 566000 / 690827 lineas (81.9%)
# Revisado 566500 / 690827 lineas (82.0%)
# Revisado 567000 / 690827 lineas (82.1%)
# Revisado 567500 / 690827 lineas (82.1%)
# Revisado 568000 / 690827 lineas (82.2%)
# Revisado 568500 / 690827 lineas (82.3%)
# Revisado 569000 / 690827 lineas (82.4%)
# Revisado 569500 / 690827 lineas (82.4%)
# Revisado 570000 / 690827 lineas (82.5%)
#   ...procesadas 570000 filas
# Revisado 570500 / 690827 lineas (82.6%)
# Revisado 571000 / 690827 lineas (82.7%)
# Revisado 571500 / 690827 lineas (82.7%)
# Revisado 572000 / 690827 lineas (82.8%)
# Revisado 572500 / 690827 lineas (82.9%)
# Revisado 573000 / 690827 lineas (82.9%)
# Revisado 573500 / 690827 lineas (83.0%)
# Revisado 574000 / 690827 lineas (83.1%)
# Revisado 574500 / 690827 lineas (83.2%)
# Revisado 575000 / 690827 lineas (83.2%)
# Revisado 575500 / 690827 lineas (83.3%)
# Revisado 576000 / 690827 lineas (83.4%)
# Revisado 576500 / 690827 lineas (83.5%)
# Revisado 577000 / 690827 lineas (83.5%)
# Revisado 577500 / 690827 lineas (83.6%)
# Revisado 578000 / 690827 lineas (83.7%)
# Revisado 578500 / 690827 lineas (83.7%)
# Revisado 579000 / 690827 lineas (83.8%)
# Revisado 579500 / 690827 lineas (83.9%)
# Revisado 580000 / 690827 lineas (84.0%)
#   ...procesadas 580000 filas
# Revisado 580500 / 690827 lineas (84.0%)
# Revisado 581000 / 690827 lineas (84.1%)
# Revisado 581500 / 690827 lineas (84.2%)
# Revisado 582000 / 690827 lineas (84.2%)
# Revisado 582500 / 690827 lineas (84.3%)
# Revisado 583000 / 690827 lineas (84.4%)
# Revisado 583500 / 690827 lineas (84.5%)
# Revisado 584000 / 690827 lineas (84.5%)
# Revisado 584500 / 690827 lineas (84.6%)
# Revisado 585000 / 690827 lineas (84.7%)
# Revisado 585500 / 690827 lineas (84.8%)
# Revisado 586000 / 690827 lineas (84.8%)
# Revisado 586500 / 690827 lineas (84.9%)
# Revisado 587000 / 690827 lineas (85.0%)
# Revisado 587500 / 690827 lineas (85.0%)
# Revisado 588000 / 690827 lineas (85.1%)
# Revisado 588500 / 690827 lineas (85.2%)
# Revisado 589000 / 690827 lineas (85.3%)
# Revisado 589500 / 690827 lineas (85.3%)
# Revisado 590000 / 690827 lineas (85.4%)
#   ...procesadas 590000 filas
# Revisado 590500 / 690827 lineas (85.5%)
# Revisado 591000 / 690827 lineas (85.5%)
# Revisado 591500 / 690827 lineas (85.6%)
# Revisado 592000 / 690827 lineas (85.7%)
# Revisado 592500 / 690827 lineas (85.8%)
# Revisado 593000 / 690827 lineas (85.8%)
# Revisado 593500 / 690827 lineas (85.9%)
# Revisado 594000 / 690827 lineas (86.0%)
# Revisado 594500 / 690827 lineas (86.1%)
# Revisado 595000 / 690827 lineas (86.1%)
# Revisado 595500 / 690827 lineas (86.2%)
# Revisado 596000 / 690827 lineas (86.3%)
# Revisado 596500 / 690827 lineas (86.3%)
# Revisado 597000 / 690827 lineas (86.4%)
# Revisado 597500 / 690827 lineas (86.5%)
# Revisado 598000 / 690827 lineas (86.6%)
# Revisado 598500 / 690827 lineas (86.6%)
# Revisado 599000 / 690827 lineas (86.7%)
# Revisado 599500 / 690827 lineas (86.8%)
# Revisado 600000 / 690827 lineas (86.9%)
#   ...procesadas 600000 filas
# Revisado 600500 / 690827 lineas (86.9%)
# Revisado 601000 / 690827 lineas (87.0%)
# Revisado 601500 / 690827 lineas (87.1%)
# Revisado 602000 / 690827 lineas (87.1%)
# Revisado 602500 / 690827 lineas (87.2%)
# Revisado 603000 / 690827 lineas (87.3%)
# Revisado 603500 / 690827 lineas (87.4%)
# Revisado 604000 / 690827 lineas (87.4%)
# Revisado 604500 / 690827 lineas (87.5%)
# Revisado 605000 / 690827 lineas (87.6%)
# Revisado 605500 / 690827 lineas (87.6%)
# Revisado 606000 / 690827 lineas (87.7%)
# Revisado 606500 / 690827 lineas (87.8%)
# Revisado 607000 / 690827 lineas (87.9%)
# Revisado 607500 / 690827 lineas (87.9%)
# Revisado 608000 / 690827 lineas (88.0%)
# Revisado 608500 / 690827 lineas (88.1%)
# Revisado 609000 / 690827 lineas (88.2%)
# Revisado 609500 / 690827 lineas (88.2%)
# Revisado 610000 / 690827 lineas (88.3%)
#   ...procesadas 610000 filas
# Revisado 610500 / 690827 lineas (88.4%)
# Revisado 611000 / 690827 lineas (88.4%)
# Revisado 611500 / 690827 lineas (88.5%)
# Revisado 612000 / 690827 lineas (88.6%)
# Revisado 612500 / 690827 lineas (88.7%)
# Revisado 613000 / 690827 lineas (88.7%)
# Revisado 613500 / 690827 lineas (88.8%)
# Revisado 614000 / 690827 lineas (88.9%)
# Revisado 614500 / 690827 lineas (89.0%)
# Revisado 615000 / 690827 lineas (89.0%)
# Revisado 615500 / 690827 lineas (89.1%)
# Revisado 616000 / 690827 lineas (89.2%)
# Revisado 616500 / 690827 lineas (89.2%)
# Revisado 617000 / 690827 lineas (89.3%)
# Revisado 617500 / 690827 lineas (89.4%)
# Revisado 618000 / 690827 lineas (89.5%)
# Revisado 618500 / 690827 lineas (89.5%)
# Revisado 619000 / 690827 lineas (89.6%)
# Revisado 619500 / 690827 lineas (89.7%)
# Revisado 620000 / 690827 lineas (89.7%)
#   ...procesadas 620000 filas
# Revisado 620500 / 690827 lineas (89.8%)
# Revisado 621000 / 690827 lineas (89.9%)
# Revisado 621500 / 690827 lineas (90.0%)
# Revisado 622000 / 690827 lineas (90.0%)
# Revisado 622500 / 690827 lineas (90.1%)
# Revisado 623000 / 690827 lineas (90.2%)
# Revisado 623500 / 690827 lineas (90.3%)
# Revisado 624000 / 690827 lineas (90.3%)
# Revisado 624500 / 690827 lineas (90.4%)
# Revisado 625000 / 690827 lineas (90.5%)
# Revisado 625500 / 690827 lineas (90.5%)
# Revisado 626000 / 690827 lineas (90.6%)
# Revisado 626500 / 690827 lineas (90.7%)
# Revisado 627000 / 690827 lineas (90.8%)
# Revisado 627500 / 690827 lineas (90.8%)
# Revisado 628000 / 690827 lineas (90.9%)
# Revisado 628500 / 690827 lineas (91.0%)
# Revisado 629000 / 690827 lineas (91.1%)
# Revisado 629500 / 690827 lineas (91.1%)
# Revisado 630000 / 690827 lineas (91.2%)
#   ...procesadas 630000 filas
# Revisado 630500 / 690827 lineas (91.3%)
# Revisado 631000 / 690827 lineas (91.3%)
# Revisado 631500 / 690827 lineas (91.4%)
# Revisado 632000 / 690827 lineas (91.5%)
# Revisado 632500 / 690827 lineas (91.6%)
# Revisado 633000 / 690827 lineas (91.6%)
# Revisado 633500 / 690827 lineas (91.7%)
# Revisado 634000 / 690827 lineas (91.8%)
# Revisado 634500 / 690827 lineas (91.8%)
# Revisado 635000 / 690827 lineas (91.9%)
# Revisado 635500 / 690827 lineas (92.0%)
# Revisado 636000 / 690827 lineas (92.1%)
# Revisado 636500 / 690827 lineas (92.1%)
# Revisado 637000 / 690827 lineas (92.2%)
# Revisado 637500 / 690827 lineas (92.3%)
# Revisado 638000 / 690827 lineas (92.4%)
# Revisado 638500 / 690827 lineas (92.4%)
# Revisado 639000 / 690827 lineas (92.5%)
# Revisado 639500 / 690827 lineas (92.6%)
# Revisado 640000 / 690827 lineas (92.6%)
#   ...procesadas 640000 filas
# Revisado 640500 / 690827 lineas (92.7%)
# Revisado 641000 / 690827 lineas (92.8%)
# Revisado 641500 / 690827 lineas (92.9%)
# Revisado 642000 / 690827 lineas (92.9%)
# Revisado 642500 / 690827 lineas (93.0%)
# Revisado 643000 / 690827 lineas (93.1%)
# Revisado 643500 / 690827 lineas (93.1%)
# Revisado 644000 / 690827 lineas (93.2%)
# Revisado 644500 / 690827 lineas (93.3%)
# Revisado 645000 / 690827 lineas (93.4%)
# Revisado 645500 / 690827 lineas (93.4%)
# Revisado 646000 / 690827 lineas (93.5%)
# Revisado 646500 / 690827 lineas (93.6%)
# Revisado 647000 / 690827 lineas (93.7%)
# Revisado 647500 / 690827 lineas (93.7%)
# Revisado 648000 / 690827 lineas (93.8%)
# Revisado 648500 / 690827 lineas (93.9%)
# Revisado 649000 / 690827 lineas (93.9%)
# Revisado 649500 / 690827 lineas (94.0%)
# Revisado 650000 / 690827 lineas (94.1%)
#   ...procesadas 650000 filas
# Revisado 650500 / 690827 lineas (94.2%)
# Revisado 651000 / 690827 lineas (94.2%)
# Revisado 651500 / 690827 lineas (94.3%)
# Revisado 652000 / 690827 lineas (94.4%)
# Revisado 652500 / 690827 lineas (94.5%)
# Revisado 653000 / 690827 lineas (94.5%)
# Revisado 653500 / 690827 lineas (94.6%)
# Revisado 654000 / 690827 lineas (94.7%)
# Revisado 654500 / 690827 lineas (94.7%)
# Revisado 655000 / 690827 lineas (94.8%)
# Revisado 655500 / 690827 lineas (94.9%)
# Revisado 656000 / 690827 lineas (95.0%)
# Revisado 656500 / 690827 lineas (95.0%)
# Revisado 657000 / 690827 lineas (95.1%)
# Revisado 657500 / 690827 lineas (95.2%)
# Revisado 658000 / 690827 lineas (95.2%)
# Revisado 658500 / 690827 lineas (95.3%)
# Revisado 659000 / 690827 lineas (95.4%)
# Revisado 659500 / 690827 lineas (95.5%)
# Revisado 660000 / 690827 lineas (95.5%)
#   ...procesadas 660000 filas
# Revisado 660500 / 690827 lineas (95.6%)
# Revisado 661000 / 690827 lineas (95.7%)
# Revisado 661500 / 690827 lineas (95.8%)
# Revisado 662000 / 690827 lineas (95.8%)
# Revisado 662500 / 690827 lineas (95.9%)
# Revisado 663000 / 690827 lineas (96.0%)
# Revisado 663500 / 690827 lineas (96.0%)
# Revisado 664000 / 690827 lineas (96.1%)
# Revisado 664500 / 690827 lineas (96.2%)
# Revisado 665000 / 690827 lineas (96.3%)
# Revisado 665500 / 690827 lineas (96.3%)
# Revisado 666000 / 690827 lineas (96.4%)
# Revisado 666500 / 690827 lineas (96.5%)
# Revisado 667000 / 690827 lineas (96.6%)
# Revisado 667500 / 690827 lineas (96.6%)
# Revisado 668000 / 690827 lineas (96.7%)
# Revisado 668500 / 690827 lineas (96.8%)
# Revisado 669000 / 690827 lineas (96.8%)
# Revisado 669500 / 690827 lineas (96.9%)
# Revisado 670000 / 690827 lineas (97.0%)
#   ...procesadas 670000 filas
# Revisado 670500 / 690827 lineas (97.1%)
# Revisado 671000 / 690827 lineas (97.1%)
# Revisado 671500 / 690827 lineas (97.2%)
# Revisado 672000 / 690827 lineas (97.3%)
# Revisado 672500 / 690827 lineas (97.3%)
# Revisado 673000 / 690827 lineas (97.4%)
# Revisado 673500 / 690827 lineas (97.5%)
# Revisado 674000 / 690827 lineas (97.6%)
# Revisado 674500 / 690827 lineas (97.6%)
# Revisado 675000 / 690827 lineas (97.7%)
# Revisado 675500 / 690827 lineas (97.8%)
# Revisado 676000 / 690827 lineas (97.9%)
# Revisado 676500 / 690827 lineas (97.9%)
# Revisado 677000 / 690827 lineas (98.0%)
# Revisado 677500 / 690827 lineas (98.1%)
# Revisado 678000 / 690827 lineas (98.1%)
# Revisado 678500 / 690827 lineas (98.2%)
# Revisado 679000 / 690827 lineas (98.3%)
# Revisado 679500 / 690827 lineas (98.4%)
# Revisado 680000 / 690827 lineas (98.4%)
#   ...procesadas 680000 filas
# Revisado 680500 / 690827 lineas (98.5%)
# Revisado 681000 / 690827 lineas (98.6%)
# Revisado 681500 / 690827 lineas (98.6%)
# Revisado 682000 / 690827 lineas (98.7%)
# Revisado 682500 / 690827 lineas (98.8%)
# Revisado 683000 / 690827 lineas (98.9%)
# Revisado 683500 / 690827 lineas (98.9%)
# Revisado 684000 / 690827 lineas (99.0%)
# Revisado 684500 / 690827 lineas (99.1%)
# Revisado 685000 / 690827 lineas (99.2%)
# Revisado 685500 / 690827 lineas (99.2%)
# Revisado 686000 / 690827 lineas (99.3%)
# Revisado 686500 / 690827 lineas (99.4%)
# Revisado 687000 / 690827 lineas (99.4%)
# Revisado 687500 / 690827 lineas (99.5%)
# Revisado 688000 / 690827 lineas (99.6%)
# Revisado 688500 / 690827 lineas (99.7%)
# Revisado 689000 / 690827 lineas (99.7%)
# Revisado 689500 / 690827 lineas (99.8%)
# Revisado 690000 / 690827 lineas (99.9%)
#   ...procesadas 690000 filas
# Revisado 690500 / 690827 lineas (100.0%)
# Revisado 690827 / 690827 lineas (100.0%)
#
# Resumen Observacion_Prerrequisito:
# Observacion_Prerrequisito
# No tiene pre requisito                378951
# Prerrequisito cumplido                259503
# Cumple parcialmente el requisito       29549
# Tiene pre requisito pero no cumple     22824
# Name: count, dtype: int64
# === FIN evaluar_prerrequisitos_con_cadena ===

# %%
guardar_resultados(df_final)
# Out:
# ✓ Guardando resultados en: Resultados v6/resultados_prerrequisitos_v6_cadenas_2026-02-02175405.csv ...
# ✓ Resultados guardados en: Resultados v6/resultados_prerrequisitos_v6_cadenas_2026-02-02175405.csv
# Columnas en el archivo: 298
